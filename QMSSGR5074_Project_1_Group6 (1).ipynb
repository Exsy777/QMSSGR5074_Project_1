# %% [markdown]
# # Student Identification & Github Repository URL
#
# Please complete the following information before submitting your notebook.
#
# **UNI:xy2703, zy2744, jz3998**
# **Full Name: Esme You, Ziyan Yu, Joey Zhu** (alphabetical order)
#
# **Public GitHub Repository URL (Final Project Report & Code):** https://github.com/Exsy777/QMSSGR5074_Project_1.git

# %% [markdown]
# # World Happiness Classification Competition
#
# ## Project Objectives
#
# The objective of this project is to build and evaluate machine learning models that classify countries into happiness categories based on economic, social, and development indicators. Through this process, the project aims to deepen understanding of how machine learning models learn patterns from data and how model design choices influence predictive performance.
#
# ---
#
# ## Project Workflow & Outline
#
# 1. **Load and Merge Datasets**
#    - Import all relevant datasets
#    - Perform necessary joins and validation
#
# 2. **Data Preprocessing**
#    - Build preprocessing pipelines using `sklearn`'s `ColumnTransformer`
#    - Handle missing values, encoding, scaling, and feature engineering
#
# 3. **Model Training**
#    - Fit the model using the processed data
#    - Save both the preprocessing pipeline and trained model
#
# 4. **Prediction and Evaluation**
#    - Generate predictions
#    - Evaluate performance using appropriate metrics
#
# 5. **Hyperparameter Tuning**
#    - Systematically tune model parameters
#    - Compare performance across configurations
#
# 6. **Deep Learning Experimentation**
#    - Implement and evaluate a neural network approach
#    - Compare results with classical ML models
#
# 7. **Model Explainability (SHAP)**
#    - Apply SHAP for feature importance analysis
#    - Interpret and explain model decisions

# %% [markdown]
# ---
#
# ## 0. Loading Datasets
#
# In this section, the World Happiness 2023 datasets are loaded into the notebook environment to serve as the primary data sources for the analysis. The datasets are inspected to understand their structure, including the number of observations, available variables, column names, and data types. This initial inspection helps verify that the datasets were imported correctly and ensures that key variables required for later analysis are present.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# Import drive to Google Colab
from google.colab import drive
drive.mount('/content/drive')

# Load the dataset
whr_df = pd.read_csv('/content/drive/MyDrive/Projects in ML/WHR_2023.csv')

# Inspect the first few rows to understand the structure
whr_df
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#               country                        region  happiness_score  \
# 0             Finland                Western Europe            7.804
# 1             Denmark                Western Europe            7.586
# 2             Iceland                Western Europe            7.530
# 3              Israel  Middle East and North Africa            7.473
# 4         Netherlands                Western Europe            7.403
# ..                ...                           ...              ...
# 132  Congo (Kinshasa)            Sub-Saharan Africa            3.207
# 133          Zimbabwe            Sub-Saharan Africa            3.204
# 134      Sierra Leone            Sub-Saharan Africa            3.138
# 135           Lebanon  Middle East and North Africa            2.392
# 136       Afghanistan                    South Asia            1.859
#
#      gdp_per_capita  social_support  healthy_life_expectancy  \
# 0             1.888           1.585                    0.535
# 1             1.949           1.548                    0.537
# 2             1.926           1.620                    0.559
# 3             1.833           1.521                    0.577
# 4             1.942           1.488                    0.545
# ..              ...             ...                      ...
# 132           0.531           0.784                    0.105
# 133           0.758           0.881                    0.069
# 134           0.670           0.540                    0.092
# 135           1.417           0.476                    0.398
# 136           0.645           0.000                    0.087
#
#      freedom_to_make_life_choices  generosity  perceptions_of_corruption
# 0                           0.772       0.126                      0.535
# 1                           0.734       0.208                      0.525
# 2                           0.738       0.250                      0.187
# 3                           0.569       0.124                      0.158
# 4                           0.672       0.251                      0.394
# ..                            ...         ...                        ...
# 132                         0.375       0.183                      0.068
# 133                         0.363       0.112                      0.117
# 134                         0.371       0.193                      0.051
# 135                         0.123       0.061                      0.027
# 136                         0.000       0.093                      0.059
#
# [137 rows x 9 columns]

# %%
# Convert the regression target ('happiness_score') into classification labels

# Define quartiles
whr_df['happiness_category'] = pd.qcut(whr_df['happiness_score'],
                                       q=5,
                                       # 4 happiness categories: Very Low, Low, High, Very High
                                       labels=['Very Low', 'Low','Average', 'High', 'Very High'])

# Select features and target
X = whr_df.drop(columns=['happiness_score', 'happiness_category'])
y = whr_df['happiness_category']

# Split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# Convert y_train and y_test to numerical labels
y_train_labels = y_train.astype('category').cat.codes
# y_test_labels = ## Complete in a similar manner as above. TODO
y_test_labels = y_test.astype('category').cat.codes

# %% [markdown]
# ### Target Variable Encoding and Label Representation
#
# The target variable is converted into a categorical format and encoded into numerical codes so it can be used by machine learning models that require numeric inputs. The encoded version (y_train_labels) provides integer representations of the categories, while the original variable (y_train) retains the human-readable labels used for interpretation and evaluation.

# %% [markdown]
# 1. `y_train.astype('category').cat.codes` converts the categorical target variable into numerical labels that machine learning models can use. The astype('category') step ensures the variable is treated as a categorical data type, and .cat.codes assigns an integer value to each category (for example, Very Low = 0, Low = 1, Average = 2, High = 3, Very High = 4).
# 2. The difference between y_train_labels and y_train is that y_train contains the original categorical class labels, while y_train_labels contains their numeric representations. Both variables describe the same target information, but the numeric version is required for model training and computation, whereas the original categorical labels are easier to interpret when analyzing results.

# %% [markdown]
# ### Add New Data

# %%
# Truncated and cleaned up region data to merge
countrydata=pd.read_csv('/content/drive/MyDrive/Projects in ML/newcountryvars.csv')

countrydata.head()
# Out:
#   country_name  population  population_below_poverty_line       hdi  \
# 0        India  1339180127                           21.9  0.623559
# 1      Nigeria   190886311                           70.0  0.527105
# 2       Mexico   129163276                           46.2  0.761683
# 3     Pakistan   197015955                           29.5  0.550354
# 4   Bangladesh   164669751                           31.5  0.578824
#
#    life_expectancy  expected_years_of_schooling  mean_years_of_schooling  \
# 0           68.322                    11.696590                 6.298834
# 1           53.057                     9.970482                 6.000000
# 2           76.972                    13.299090                 8.554985
# 3           66.365                     8.106910                 5.089460
# 4           71.985                    10.178706                 5.241577
#
#             gni
# 0   5663.474799
# 1   5442.901264
# 2  16383.106680
# 3   5031.173074
# 4   3341.490722

# %%
# Organize datasets
whr_countries = set(X_train['country'].dropna().unique())
new_countries = set(countrydata['country_name'].dropna().unique())

common_countries = whr_countries.intersection(new_countries)
only_in_whr = whr_countries - new_countries
only_in_new = new_countries - whr_countries

print(f"Countries in WHR (train): {len(whr_countries)}")
print(f"Countries in newcountryvars: {len(new_countries)}")
print(f"Common countries: {len(common_countries)}")
print(f"Only in WHR: {len(only_in_whr)}")
print(f"Only in newcountryvars: {len(only_in_new)}")

# Merge
X_train = X_train.merge(countrydata, left_on='country', right_on='country_name', how='left')
X_test  = X_test.merge(countrydata, left_on='country', right_on='country_name', how='left')


# Drop duplicate columns created by prior merges (_x/_y)
X_train = X_train.loc[:, ~X_train.columns.str.endswith(('_x', '_y'))]
X_test  = X_test.loc[:, ~X_test.columns.str.endswith(('_x', '_y'))]
# Out:
# Countries in WHR (train): 95
# Countries in newcountryvars: 174
# Common countries: 89
# Only in WHR: 6
# Only in newcountryvars: 85

# %%
X_train.head(1)
# Out:
#       country              region  gdp_per_capita  social_support  \
# 0  Madagascar  Sub-Saharan Africa           0.632           0.779
#
#    healthy_life_expectancy  freedom_to_make_life_choices  generosity  \
# 0                    0.178                         0.187       0.177
#
#    perceptions_of_corruption country_name  population  \
# 0                      0.134   Madagascar  25570895.0
#
#    population_below_poverty_line       hdi  life_expectancy  \
# 0                           70.7  0.512149           65.515
#
#    expected_years_of_schooling  mean_years_of_schooling          gni
# 0                     10.34614                 6.145955  1319.699397

# %% [markdown]
# ---
#
# ## 1. Exploratory Data Analysis and Visualization (EDAV)

# %%
print(X_train.dtypes)
# Out:
# country                           object
# region                            object
# gdp_per_capita                   float64
# social_support                   float64
# healthy_life_expectancy          float64
# freedom_to_make_life_choices     float64
# generosity                       float64
# perceptions_of_corruption        float64
# country_name                      object
# population                       float64
# population_below_poverty_line    float64
# hdi                              float64
# life_expectancy                  float64
# expected_years_of_schooling      float64
# mean_years_of_schooling          float64
# gni                              float64
# dtype: object

# %% [markdown]
# ### Observations

# %% [markdown]
# The dataset contains both categorical and numerical variables. The categorical variables include country and region, while the remaining features are continuous socioeconomic indicators such as GDP per capita, social support, life expectancy, HDI, GNI, and education-related variables. Most numerical variables are stored as float64, which is appropriate for modeling. After merging the additional country-level dataset, several development indicators (e.g., population, HDI, and GNI) were successfully appended. The presence of both categorical and numerical data types indicates that separate preprocessing strategies will be required. Categorical variables will need encoding, and numerical variables may require scaling and imputation. The dataset appears structurally consistent after removing duplicate merge columns, and it is suitable for further exploratory analysis and modeling.

# %% [markdown]
# ### Missing Values Analysis
#
# In this section, the number and percentage of missing values are calculated for each variable to identify potential data gaps and inform appropriate imputation strategies before modeling.

# %%
# Compute missing counts and percentages
missing_summary = pd.DataFrame({
    "Missing Count": X_train.isnull().sum(),
    "Missing Percentage (%)": (X_train.isnull().sum() / len(X_train)) * 100
})
# Sort by highest missing percentage
missing_summary = missing_summary.sort_values(
    by="Missing Percentage (%)",
    ascending=False
)

missing_summary
# Out:
#                                Missing Count  Missing Percentage (%)
# population_below_poverty_line             16               16.842105
# life_expectancy                            7                7.368421
# mean_years_of_schooling                    7                7.368421
# expected_years_of_schooling                7                7.368421
# gni                                        7                7.368421
# population                                 6                6.315789
# hdi                                        6                6.315789
# country_name                               6                6.315789
# perceptions_of_corruption                  0                0.000000
# generosity                                 0                0.000000
# freedom_to_make_life_choices               0                0.000000
# healthy_life_expectancy                    0                0.000000
# social_support                             0                0.000000
# gdp_per_capita                             0                0.000000
# region                                     0                0.000000
# country                                    0                0.000000

# %% [markdown]
# ### Distribution of Key Numerical Features
#
# In this section, histograms are used to visualize the distributions of selected numerical variables that may influence the target variable. Examining these distributions helps identify patterns such as skewness, concentration of values, and potential outliers that may affect model performance or require transformation.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Select relevant numerical features likely to influence happiness
num_features = [
    'gdp_per_capita',
    'social_support',
    'healthy_life_expectancy',
    'freedom_to_make_life_choices',
    'hdi',
    'gni'
]

# Remove any features not present (safe check)
num_features = [col for col in num_features if col in X_train.columns]

plt.figure(figsize=(14, 10))

for i, col in enumerate(num_features):
    plt.subplot(3, 2, i+1)
    sns.histplot(X_train[col], kde=True, bins=20)
    plt.title(f'Distribution of {col}')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Distribution of Categorical Variables
#
# In this section, the distributions of relevant categorical variables are visualized using bar charts to examine how observations are distributed across categories. This helps identify potential class imbalances or patterns that may influence model training and interpretation.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create cross-tab
region_happiness = pd.crosstab(X_train['region'], y_train)

# Plot stacked bar chart
region_happiness.plot(kind='bar', stacked=True, figsize=(10,6))

plt.title("Happiness Category Distribution by Region")
plt.xlabel("Region")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.legend(title="Happiness Category")
plt.tight_layout()
plt.show()

# Proportion Plot
region_prop = pd.crosstab(X_train['region'], y_train, normalize='index')

region_prop.plot(kind='bar', stacked=True, figsize=(10,6))

plt.title("Proportion of Happiness Categories by Region")
plt.xlabel("Region")
plt.ylabel("Proportion")
plt.xticks(rotation=45)
plt.legend(title="Happiness Category")
plt.tight_layout()
plt.show()

# %% [markdown]
# The results indicate systematic regional clustering of happiness levels. Developed regions tend to concentrate in higher happiness categories, while lower-income regions exhibit greater representation in lower categories. This geographic structure supports the inclusion of region as a meaningful explanatory variable in the modeling pipeline.

# %% [markdown]
# ### Feature Correlation Analysis
#
# In this section, correlations among numerical features are examined using Pearson, Spearman, and Kendall correlation coefficients. Correlation matrices and heatmaps are used to visualize the strength and direction of relationships between variables. This analysis helps identify strong positive or negative associations and detect potential multicollinearity among development indicators, which may influence feature selection and modeling strategies.

# %%
# Select only numerical columns
numeric_cols = X_train.select_dtypes(include=['float64', 'int64'])

# Compute correlation matrices
pearson_corr = numeric_cols.corr(method='pearson')
spearman_corr = numeric_cols.corr(method='spearman')
kendall_corr = numeric_cols.corr(method='kendall')

# Plot Pearson
plt.figure(figsize=(10,8))
sns.heatmap(pearson_corr, cmap='coolwarm', center=0)
plt.title("Pearson Correlation Matrix")
plt.show()

# Plot Spearman
plt.figure(figsize=(10,8))
sns.heatmap(spearman_corr, cmap='coolwarm', center=0)
plt.title("Spearman Correlation Matrix")
plt.show()

# Plot Kendall
plt.figure(figsize=(10,8))
sns.heatmap(kendall_corr, cmap='coolwarm', center=0)
plt.title("Kendall Correlation Matrix")
plt.show()

# %% [markdown]
# The correlation analysis shows strong positive relationships among key development indicators such as GDP per capita, GNI, HDI, life expectancy, and education variables. These variables are highly correlated across Pearson, Spearman, and Kendall measures, indicating consistent linear and monotonic associations. Poverty rate exhibits strong negative correlations with income, education, and health indicators. The high correlation between GDP and GNI, as well as between HDI and its components, suggests potential multicollinearity. While this is less concerning for tree-based models, it may affect interpretability in linear models.

# %% [markdown]
# ### Bivariate Analysis and Relationship Exploration
#
# In this section, relationships between features and the target variable are examined using bivariate visualizations and summary statistics. Scatter plots, box plots, and grouped comparisons help illustrate how feature distributions vary across happiness categories, while correlation tables highlight associations between variables. This analysis identifies meaningful patterns and relationships that may influence model performance and feature selection.

# %%
# Combine features and target for plotting
train_df = X_train.copy()
train_df["happiness_category"] = y_train.values

# Boxplots of key numerical variables vs target
key_features = [
    "gdp_per_capita",
    "social_support",
    "healthy_life_expectancy",
    "hdi",
    "gni"
]

key_features = [col for col in key_features if col in train_df.columns]

plt.figure(figsize=(15,10))
for i, col in enumerate(key_features):
    plt.subplot(3, 2, i+1)
    sns.boxplot(x="happiness_category", y=col, data=train_df)
    plt.xticks(rotation=45)
    plt.title(f"{col} by Happiness Category")
plt.tight_layout()
plt.show()


# Compare mean values of key features across happiness categories
grouped_means = train_df.groupby("happiness_category")[key_features].mean()

grouped_means
# Out:
# /tmp/ipykernel_303/415299372.py:27: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_means = train_df.groupby("happiness_category")[key_features].mean()
#                     gdp_per_capita  social_support  healthy_life_expectancy  \
# happiness_category
# Very Low                  0.898474        0.769421                 0.205947
# Low                       1.117368        0.919947                 0.260000
# Average                   1.480421        1.276842                 0.430316
# High                      1.632684        1.349105                 0.445158
# Very High                 1.911316        1.473053                 0.525789
#
#                          hdi           gni
# happiness_category
# Very Low            0.539376   3400.339025
# Low                 0.587020   6735.363926
# Average             0.748964  14101.809331
# High                0.805969  23301.915609
# Very High           0.902453  42650.833269

# %% [markdown]
# The bivariate analysis reveals a strong and consistent upward trend in development indicators across happiness categories. GDP per capita, GNI, HDI, life expectancy, and social support increase progressively from “Very Low” to “Very High” groups, indicating a clear association between higher socioeconomic development and greater happiness classification. The stepwise increase in group means suggests a structured gradient rather than random variation. These patterns imply that economic capacity and human development metrics are likely to play a central role in model prediction and may provide substantial discriminatory power between happiness levels.

# %% [markdown]
# ### Outlier Detection
#
# In this section, potential outliers in numerical features are identified using methods such as box plots, Z-score analysis, and the Interquartile Range (IQR) approach. Detecting extreme values helps determine whether observations represent genuine variation or anomalies that may require transformation or special handling during preprocessing.

# %%
import numpy as np
from scipy import stats

# Z-score method
z_scores = np.abs(stats.zscore(numeric_cols, nan_policy='omit'))
z_outliers = (z_scores > 3).sum(axis=0)

z_outlier_summary = pd.Series(z_outliers, index=numeric_cols.columns)
z_outlier_summary.sort_values(ascending=False)


# IQR method
Q1 = numeric_cols.quantile(0.25)
Q3 = numeric_cols.quantile(0.75)
IQR = Q3 - Q1

iqr_outliers = ((numeric_cols < (Q1 - 1.5 * IQR)) |
                (numeric_cols > (Q3 + 1.5 * IQR))).sum()

iqr_outliers.sort_values(ascending=False)
# Out:
# perceptions_of_corruption        10
# population                        9
# population_below_poverty_line     4
# freedom_to_make_life_choices      3
# social_support                    2
# gni                               2
# gdp_per_capita                    1
# generosity                        1
# healthy_life_expectancy           0
# hdi                               0
# life_expectancy                   0
# expected_years_of_schooling       0
# mean_years_of_schooling           0
# dtype: int64

# %% [markdown]
# Outlier detection reveals that perceptions of corruption and population contain the largest number of extreme values. Population outliers are expected due to the substantial scale differences between small and highly populous countries. Similarly, perceptions of corruption may exhibit extreme values reflecting significant institutional differences across nations. Income-related variables such as GDP and GNI show limited but present high-end outliers, likely corresponding to very high-income countries. Development indicators such as HDI, life expectancy, and schooling variables do not exhibit substantial outlier behavior.
#
# Because these values represent genuine cross-country heterogeneity rather than data errors, they should be retained. However, log transformation of highly skewed variables such as GDP, GNI, and population may help stabilize variance and reduce the influence of extreme observations. Tree-based models are generally robust to outliers, so removal is not recommended.

# %% [markdown]
# ### Observations and General Comments

# %% [markdown]
# Economic indicators such as GDP per capita, GNI, HDI, life expectancy, and education variables increase consistently across happiness levels, indicating strong predictive relevance. Regional patterns suggest geographic clustering of development and happiness outcomes. Missing values are primarily introduced through the merged country-level dataset and will require imputation rather than row removal to preserve sample size. Outlier detection shows extreme values mainly in population and high-income variables; these reflect genuine cross-country variation and should be retained, though log transformation of scale-heavy variables (e.g., GDP, GNI, population) may improve stability. Prior to modeling, categorical variables must be encoded, numerical features scaled, and missing values imputed to ensure a robust preprocessing pipeline.

# %% [markdown]
# ---
#
# ## 2. Feature Engineering
#
# In this section, log transformations are applied to highly skewed numerical features to reduce the influence of extreme values and stabilize variance. Normalizing skewed variables helps improve model stability and can make relationships between variables easier for machine learning models to learn.

# %%
# Identify skewed, scale-heavy variables
log_features = ['gdp_per_capita', 'gni', 'population']

# Apply log(1 + x) transformation safely
for col in log_features:
    if col in X_train.columns:
        X_train[col] = np.log1p(X_train[col])
        X_test[col] = np.log1p(X_test[col])

# Optional: verify transformation
X_train[log_features].head()
# Out:
#    gdp_per_capita       gni  population
# 0        0.489806  7.185917   17.056965
# 1        0.741461  8.168561   15.301692
# 2        0.866680  9.254377   14.939026
# 3        0.679048  7.863876   16.003957
# 4        0.857814  8.904088   17.604754

# %% [markdown]
# Interaction features are created to capture combined effects between related variables that may influence the target outcome. By modeling interactions between features such as economic indicators and social factors, the model can better represent nonlinear relationships and potentially improve predictive performance.

# %%
# Create interaction features
# Economic capacity × social support
if all(col in X_train.columns for col in ['gdp_per_capita', 'social_support']):
    X_train['gdp_social_interaction'] = X_train['gdp_per_capita'] * X_train['social_support']
    X_test['gdp_social_interaction'] = X_test['gdp_per_capita'] * X_test['social_support']

# Human development × freedom
if all(col in X_train.columns for col in ['hdi', 'freedom_to_make_life_choices']):
    X_train['hdi_freedom_interaction'] = X_train['hdi'] * X_train['freedom_to_make_life_choices']
    X_test['hdi_freedom_interaction'] = X_test['hdi'] * X_test['freedom_to_make_life_choices']

# Verify
X_train[['gdp_social_interaction', 'hdi_freedom_interaction']].head()
# Out:
#    gdp_social_interaction  hdi_freedom_interaction
# 0                0.381559                 0.095772
# 1                0.566476                 0.164194
# 2                1.294820                 0.312304
# 3                0.847452                 0.375856
# 4                1.161480                 0.409420

# %% [markdown]
# ---
#
# ## 3. Data Preprocessing
#
# In this section, a preprocessing pipeline is constructed using sklearn’s ColumnTransformer to systematically prepare the data for modeling. The pipeline handles numerical and categorical features separately, applying appropriate transformations such as imputation, scaling, and encoding. The fitted preprocessor is saved so that the same transformations can be consistently applied to training data, test data, and future predictions.

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer, make_column_transformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder

# Create the preprocessing pipelines for both numeric and categorical data.

numeric_features = X_train.select_dtypes(include=['int64', 'float64'])
numeric_features=numeric_features.columns.tolist()

numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())])

categorical_features = ['region'] # Changed from ['region', 'sub-region']

#Replacing missing values with Modal value and then one hot encoding.
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))])

# final preprocessor object set up with ColumnTransformer
preprocessor = ColumnTransformer(transformers=[('num', numeric_transformer, numeric_features),('cat', categorical_transformer, categorical_features)])

#Fit preprocessor object
preprocess = preprocessor.fit(X_train)

# %% [markdown]
# ### Explanation

# %% [markdown]
# The preprocessing pipeline applies separate transformations to numerical and categorical features. Numerical features are imputed using the median and then standardized with StandardScaler. Median imputation was selected because many economic variables are skewed, and the median is more robust to extreme values than the mean or a constant value. Standardization ensures that variables are placed on comparable scales before modeling.
#
# Categorical variables are imputed using the most frequent category and encoded with one-hot encoding. This converts categorical features into binary indicators without imposing an ordinal structure. The handle_unknown='ignore' setting prevents errors if unseen categories appear in the test set.These steps ensure the data is complete, scaled appropriately, and formatted correctly for model training.

# %%
# function to transform data with preprocessor

def preprocessor(data):
    data.drop(['country', 'region'], axis=1)
    preprocessed_data=preprocess.transform(data)
    return preprocessed_data

# %% [markdown]
# ### Preprocessing Pipeline Components and Their Roles

# %% [markdown]
# The preprocessor object is the ColumnTransformer definition that specifies how numerical and categorical features should be transformed. It contains the transformation logic (imputation, scaling, encoding) but is not yet fitted to the data.
#
# The preprocess object is the fitted version of the preprocessor. After calling .fit(X_train), it stores the learned parameters from the training data, such as medians for imputation and scaling statistics (mean and standard deviation). This fitted object is what should be used to transform new data.
#
# The preprocessor function (e.g., preprocess_data(data)) is a wrapper function that applies the fitted preprocess object to any dataset. It provides a convenient way to consistently transform training, validation, or test data using the same learned parameters.
#
# The final preprocessed_data returned is the transformed numerical matrix produced by applying the fitted preprocessing pipeline to a dataset. It contains scaled numerical features and one-hot encoded categorical features in a format ready for model training or prediction.

# %%
# check shape of X data after preprocessing it using our new function
preprocessor(X_train).shape
# Out:
# (95, 25)

# %% [markdown]
# ---
#
# ## 4. Model Training and Saving Artifacts
# In this section, the machine learning model is trained using the preprocessed training data. After fitting the model, both the trained model and the fitted preprocessing pipeline are saved so they can be reused for future predictions, evaluation, or deployment.

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import joblib

# Transform training data using fitted preprocessor
X_train_processed = preprocess.transform(X_train)

# Define + fit Random Forest (baseline)
model = RandomForestClassifier(
    n_estimators=300,
    random_state=42
)

model.fit(X_train_processed, y_train)

# Score on training set (0–1)
train_pred = model.predict(X_train_processed)
train_score = accuracy_score(y_train, train_pred)
train_score
# Out:
# 1.0

# %% [markdown]
# ---
#
# ## 5. Model Evaluation
#
# In this section, the trained model generates predictions for the test dataset (X_test). These predictions are compared with the true labels (y_test) using evaluation metrics such as accuracy, precision, recall, and F1-score. This evaluation assesses how well the model generalizes to unseen data and provides insight into its classification performance across different target categories.

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Transform test data
X_test_processed = preprocess.transform(X_test)

# Generate predictions
prediction_labels = model.predict(X_test_processed)

# Accuracy
print("Test Accuracy:", accuracy_score(y_test, prediction_labels))

# Classification report
print("\nClassification Report:\n")
print(classification_report(y_test, prediction_labels))

# Confusion matrix
print("\nConfusion Matrix:\n")
print(confusion_matrix(y_test, prediction_labels))
# Out:
# Test Accuracy: 0.47619047619047616
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#      Average       0.50      0.50      0.50         8
#         High       0.45      0.62      0.53         8
#          Low       0.22      0.25      0.24         8
#    Very High       0.86      0.67      0.75         9
#     Very Low       0.43      0.33      0.38         9
#
#     accuracy                           0.48        42
#    macro avg       0.49      0.47      0.48        42
# weighted avg       0.50      0.48      0.48        42
#
#
# Confusion Matrix:
#
# [[4 3 1 0 0]
#  [2 5 0 1 0]
#  [2 0 2 0 4]
#  [0 3 0 6 0]
#  [0 0 6 0 3]]

# %% [markdown]
# The model achieves a test accuracy of 0.48, indicating moderate predictive performance above random guessing (0.20 for five balanced classes). Performance varies across categories. “Very High” shows strong precision and recall (F1 = 0.75), suggesting that extreme high-development countries are easier to classify. In contrast, “Low” and “Very Low” exhibit weaker precision and recall, with substantial confusion between adjacent categories. The confusion matrix shows that most misclassifications occur between neighboring happiness levels (e.g., “Low” vs “Very Low,” or “Average” vs “High”), indicating that the model struggles to distinguish borderline cases. Overall, the results suggest the model captures strong structural signals but may require hyperparameter tuning or additional feature engineering to improve discrimination among middle categories.

# %% [markdown]
# ---
#
# ## 6. Hyperparameter Experimentation
#
# The model is trained multiple times using different hyperparameter settings to evaluate how parameter choices affect predictive performance. By systematically adjusting parameters such as tree depth, number of estimators, or sample constraints, the experiments help identify configurations that improve generalization on the test data. Results from each experiment are compared, and the best-performing parameter combination is reported.

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

# Transform train/test once
X_train_processed = preprocess.transform(X_train)
X_test_processed = preprocess.transform(X_test)

# Model 2: regularized Random Forest
model_2 = RandomForestClassifier(
    n_estimators=600,          # more trees for stability
    max_depth=8,               # limit depth to reduce overfitting
    min_samples_split=5,       # require more samples to split
    min_samples_leaf=2,        # require more samples per leaf
    max_features="sqrt",       # standard RF setting for classification
    random_state=42
)

# Fit
model_2.fit(X_train_processed, y_train)

# Evaluate
pred_2 = model_2.predict(X_test_processed)

print("Model 2 Test Accuracy:", accuracy_score(y_test, pred_2))
print("\nClassification Report (Model 2):\n")
print(classification_report(y_test, pred_2))
# Out:
# Model 2 Test Accuracy: 0.5238095238095238
#
# Classification Report (Model 2):
#
#               precision    recall  f1-score   support
#
#      Average       0.56      0.62      0.59         8
#         High       0.50      0.62      0.56         8
#          Low       0.30      0.38      0.33         8
#    Very High       0.86      0.67      0.75         9
#     Very Low       0.50      0.33      0.40         9
#
#     accuracy                           0.52        42
#    macro avg       0.54      0.53      0.53        42
# weighted avg       0.55      0.52      0.53        42

# %% [markdown]
# ### Reflection on Hyperparameter Changes

# %% [markdown]
# In the second model, several hyperparameters were adjusted to reduce overfitting and improve generalization. The number of trees (n_estimators) was increased to improve stability and reduce variance. The maximum tree depth (max_depth) was limited to prevent the model from learning overly complex patterns specific to the training data. The parameters min_samples_split and min_samples_leaf were increased to require more observations before creating splits and leaf nodes, which further regularizes the model and reduces sensitivity to noise. The max_features="sqrt" setting limits the number of features considered at each split, encouraging diversity among trees.
#
# These changes improved test accuracy from 0.48 to 0.52 and increased macro F1 from 0.48 to 0.53, indicating better balanced performance across categories. The baseline model achieved perfect training accuracy (1.0), suggesting severe overfitting. After regularization, the model generalizes better, particularly in middle categories such as “Average” and “Low.” The results demonstrate that controlling model complexity improves out-of-sample performance even if training accuracy decreases.

# %%
#Evaluate Model 2:

from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Transform test data
X_test_processed = preprocess.transform(X_test)

# Generate predictions (Model 2)
prediction_labels = model_2.predict(X_test_processed)

# Accuracy
print("Model 2 Test Accuracy:", accuracy_score(y_test, prediction_labels))

# Classification report
print("\nClassification Report (Model 2):\n")
print(classification_report(y_test, prediction_labels))

# Confusion matrix
print("\nConfusion Matrix (Model 2):\n")
print(confusion_matrix(y_test, prediction_labels))
# Out:
# Model 2 Test Accuracy: 0.5238095238095238
#
# Classification Report (Model 2):
#
#               precision    recall  f1-score   support
#
#      Average       0.56      0.62      0.59         8
#         High       0.50      0.62      0.56         8
#          Low       0.30      0.38      0.33         8
#    Very High       0.86      0.67      0.75         9
#     Very Low       0.50      0.33      0.40         9
#
#     accuracy                           0.52        42
#    macro avg       0.54      0.53      0.53        42
# weighted avg       0.55      0.52      0.53        42
#
#
# Confusion Matrix (Model 2):
#
# [[5 2 1 0 0]
#  [2 5 0 1 0]
#  [2 0 3 0 3]
#  [0 3 0 6 0]
#  [0 0 6 0 3]]

# %% [markdown]
# ### Hyperparameter Tuning Strategy and Optimization Methods

# %% [markdown]
# Further manual adjustment of hyperparameters may yield incremental improvements, but repeatedly testing random combinations is inefficient and unsystematic. While the regularized model improved accuracy from 0.48 to 0.52, performance gains are modest, suggesting that manual tuning may have diminishing returns. Instead of trial-and-error experimentation, a structured approach such as GridSearchCV or RandomizedSearchCV should be used. These methods systematically explore combinations of hyperparameters using cross-validation and select the configuration that maximizes performance on validation folds. This approach is more reliable, reproducible, and statistically sound than manually testing arbitrary parameter values.

# %%
# Submit a third model using GridSearchCV

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import numpy as np

X_train_processed = preprocess.transform(X_train)
X_test_processed = preprocess.transform(X_test)

# Smaller grid (fast)
param_grid = {
    "n_estimators": np.arange(200, 601, 200),   # 200, 400, 600
    "max_depth": np.arange(6, 13, 2),           # 6, 8, 10, 12
    "min_samples_leaf": np.arange(1, 4, 1),     # 1, 2, 3
    "max_features": ["sqrt"]
}

rf = RandomForestClassifier(random_state=42)

gridmodel = GridSearchCV(
    estimator=rf,
    param_grid=param_grid,
    cv=3,
    scoring="accuracy",
    n_jobs=1            # avoids Colab parallel overhead
)

gridmodel.fit(X_train_processed, y_train)

print("best mean cross-validation score: {:.3f}".format(gridmodel.best_score_))
print("best parameters: {}".format(gridmodel.best_params_))

best_model = gridmodel.best_estimator_
prediction_labels = best_model.predict(X_test_processed)

print("\nTest Accuracy (Best Grid Model):", accuracy_score(y_test, prediction_labels))
print("\nClassification Report:\n", classification_report(y_test, prediction_labels))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, prediction_labels))
# Out:
# best mean cross-validation score: 0.537
# best parameters: {'max_depth': np.int64(6), 'max_features': 'sqrt', 'min_samples_leaf': np.int64(1), 'n_estimators': np.int64(400)}
#
# Test Accuracy (Best Grid Model): 0.5
#
# Classification Report:
#                precision    recall  f1-score   support
#
#      Average       0.56      0.62      0.59         8
#         High       0.56      0.62      0.59         8
#          Low       0.20      0.25      0.22         8
#    Very High       0.86      0.67      0.75         9
#     Very Low       0.43      0.33      0.38         9
#
#     accuracy                           0.50        42
#    macro avg       0.52      0.50      0.50        42
# weighted avg       0.53      0.50      0.51        42
#
#
# Confusion Matrix:
#  [[5 1 2 0 0]
#  [2 5 0 1 0]
#  [2 0 2 0 4]
#  [0 3 0 6 0]
#  [0 0 6 0 3]]

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Transform test data (if not already done)
X_test_processed = preprocess.transform(X_test)

# Generate predictions using best grid model
prediction_labels = best_model.predict(X_test_processed)

# Accuracy
print("Model 3 (GridSearch) Test Accuracy:", accuracy_score(y_test, prediction_labels))

# Classification report
print("\nClassification Report (Model 3):\n")
print(classification_report(y_test, prediction_labels))

# Confusion matrix
print("\nConfusion Matrix (Model 3):\n")
print(confusion_matrix(y_test, prediction_labels))
# Out:
# Model 3 (GridSearch) Test Accuracy: 0.5
#
# Classification Report (Model 3):
#
#               precision    recall  f1-score   support
#
#      Average       0.56      0.62      0.59         8
#         High       0.56      0.62      0.59         8
#          Low       0.20      0.25      0.22         8
#    Very High       0.86      0.67      0.75         9
#     Very Low       0.43      0.33      0.38         9
#
#     accuracy                           0.50        42
#    macro avg       0.52      0.50      0.50        42
# weighted avg       0.53      0.50      0.51        42
#
#
# Confusion Matrix (Model 3):
#
# [[5 1 2 0 0]
#  [2 5 0 1 0]
#  [2 0 2 0 4]
#  [0 3 0 6 0]
#  [0 0 6 0 3]]

# %%
# Gradient Boosting
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import GradientBoostingClassifier


# Transform data
X_train_processed = preprocess.transform(X_train)
X_test_processed = preprocess.transform(X_test)

# Define alternative model (Gradient Boosting)
model = GradientBoostingClassifier(
    n_estimators=200,
    learning_rate=0.05,
    max_depth=3,
    random_state=42
)

# Fit model
model.fit(X_train_processed, y_train)

# Generate predictions
prediction_labels = model.predict(X_test_processed)

# Evaluate
print("Gradient Boosting Test Accuracy:", accuracy_score(y_test, prediction_labels))

print("\nClassification Report:\n")
print(classification_report(y_test, prediction_labels))

print("\nConfusion Matrix:\n")
print(confusion_matrix(y_test, prediction_labels))
# Out:
# Gradient Boosting Test Accuracy: 0.35714285714285715
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#      Average       0.25      0.25      0.25         8
#         High       0.30      0.38      0.33         8
#          Low       0.20      0.25      0.22         8
#    Very High       0.75      0.67      0.71         9
#     Very Low       0.33      0.22      0.27         9
#
#     accuracy                           0.36        42
#    macro avg       0.37      0.35      0.36        42
# weighted avg       0.38      0.36      0.36        42
#
#
# Confusion Matrix:
#
# [[2 4 2 0 0]
#  [3 3 0 2 0]
#  [2 0 2 0 4]
#  [0 3 0 6 0]
#  [1 0 6 0 2]]

# %% [markdown]
# ### Model Parameter Configuration and Performance Analysis

# %% [markdown]
# In the regularized Random Forest model, the parameters n_estimators=600, max_depth=8, min_samples_split=5, min_samples_leaf=2, and max_features="sqrt" were defined to control model complexity and reduce overfitting. Increasing the number of trees improved stability, while limiting tree depth and requiring more samples per split and leaf reduced variance and prevented the model from memorizing the training data. This adjustment improved test accuracy from 0.48 in the baseline model (which had 1.0 training accuracy and clear overfitting) to 0.52, with macro F1 increasing from 0.48 to 0.53. The improvement in recall for middle categories such as “Average” and “Low” indicates better generalization.
#
# In the Gradient Boosting model, n_estimators=200, learning_rate=0.05, and max_depth=3 were specified. The learning rate controls how strongly each tree corrects previous errors, and a smaller value promotes gradual, more stable learning. Shallow trees (max_depth=3) reduce overfitting while allowing the model to capture nonlinear relationships. Tree-based ensemble methods worked best overall because the dataset contains nonlinear interactions, multicollinearity among development indicators, and genuine outliers—conditions under which ensemble trees are robust and effective.

# %% [markdown]
# ---
#
# ## 7. Basic Deep Learning

# %%
# Now experiment with deep learning models:
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation

# Preprocess input features
X_train_nn = preprocess.transform(X_train)
X_test_nn  = preprocess.transform(X_test)

if hasattr(X_train_nn, "toarray"):
    X_train_nn = X_train_nn.toarray()
    X_test_nn  = X_test_nn.toarray()

# Count features in input data
feature_count = X_train_nn.shape[1]

# Define Neural Network (5 layers: 128->64->64->32->output)
# Output neurons = number of classes (=5)

num_classes = y_train.nunique()

keras_model = Sequential([
    Dense(128, activation='relu', input_shape=(feature_count,)),
    Dense(64, activation='relu'),
    Dense(64, activation='relu'),
    Dense(32, activation='relu'),
    Dense(num_classes, activation='softmax')
])


# Encode categorical labels (one-hot)

y_train_cat = y_train.astype('category')
y_test_cat = y_test.astype('category')

# Ensure same category order in train/test
y_test_cat = y_test_cat.cat.set_categories(y_train_cat.cat.categories)

y_train_onehot = pd.get_dummies(y_train_cat).values
y_test_onehot  = pd.get_dummies(y_test_cat).values

# Compile model
keras_model.compile(loss='categorical_crossentropy', optimizer='sgd', metrics=['accuracy'])

# Fit model
history = keras_model.fit(
    X_train_nn, y_train_onehot,
    batch_size=20,
    epochs=300,
    validation_split=0.25,
    verbose=1
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 146ms/step - accuracy: 0.0765 - loss: 1.5962 - val_accuracy: 0.0417 - val_loss: 1.6638
# Epoch 2/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.0671 - loss: 1.5804 - val_accuracy: 0.0417 - val_loss: 1.6594
# Epoch 3/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.0988 - loss: 1.5816 - val_accuracy: 0.0417 - val_loss: 1.6558
# Epoch 4/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.0598 - loss: 1.5559 - val_accuracy: 0.0833 - val_loss: 1.6518
# Epoch 5/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.0671 - loss: 1.5651 - val_accuracy: 0.0833 - val_loss: 1.6482
# Epoch 6/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.0821 - loss: 1.5408 - val_accuracy: 0.0833 - val_loss: 1.6442
# Epoch 7/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.1147 - loss: 1.5421 - val_accuracy: 0.1250 - val_loss: 1.6391
# Epoch 8/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.1955 - loss: 1.5093 - val_accuracy: 0.1250 - val_loss: 1.6335
# Epoch 9/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.2577 - loss: 1.5289 - val_accuracy: 0.1667 - val_loss: 1.6285
# Epoch 10/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.3492 - loss: 1.5073 - val_accuracy: 0.2083 - val_loss: 1.6233
# Epoch 11/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.3558 - loss: 1.4841 - val_accuracy: 0.2917 - val_loss: 1.6180
# Epoch 12/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.3581 - loss: 1.4824 - val_accuracy: 0.2917 - val_loss: 1.6126
# Epoch 13/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.3548 - loss: 1.4793 - val_accuracy: 0.2917 - val_loss: 1.6080
# Epoch 14/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.3448 - loss: 1.4732 - val_accuracy: 0.2917 - val_loss: 1.6038
# Epoch 15/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.4094 - loss: 1.4728 - val_accuracy: 0.2917 - val_loss: 1.5994
# Epoch 16/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4357 - loss: 1.4574 - val_accuracy: 0.2917 - val_loss: 1.5946
# Epoch 17/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4040 - loss: 1.4378 - val_accuracy: 0.3333 - val_loss: 1.5901
# Epoch 18/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.4403 - loss: 1.4485 - val_accuracy: 0.3333 - val_loss: 1.5844
# Epoch 19/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.4436 - loss: 1.4251 - val_accuracy: 0.3333 - val_loss: 1.5811
# Epoch 20/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.4003 - loss: 1.4253 - val_accuracy: 0.3333 - val_loss: 1.5768
# Epoch 21/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.4807 - loss: 1.3817 - val_accuracy: 0.3333 - val_loss: 1.5717
# Epoch 22/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.4036 - loss: 1.4092 - val_accuracy: 0.3333 - val_loss: 1.5662
# Epoch 23/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.4753 - loss: 1.3781 - val_accuracy: 0.3333 - val_loss: 1.5606
# Epoch 24/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.4386 - loss: 1.3878 - val_accuracy: 0.3333 - val_loss: 1.5550
# Epoch 25/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4303 - loss: 1.3650 - val_accuracy: 0.3333 - val_loss: 1.5495
# Epoch 26/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4103 - loss: 1.3445 - val_accuracy: 0.3333 - val_loss: 1.5450
# Epoch 27/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4486 - loss: 1.3383 - val_accuracy: 0.2917 - val_loss: 1.5396
# Epoch 28/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4719 - loss: 1.3345 - val_accuracy: 0.2917 - val_loss: 1.5356
# Epoch 29/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.4436 - loss: 1.2979 - val_accuracy: 0.2917 - val_loss: 1.5302
# Epoch 30/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4653 - loss: 1.3125 - val_accuracy: 0.2917 - val_loss: 1.5246
# Epoch 31/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.4286 - loss: 1.3131 - val_accuracy: 0.2917 - val_loss: 1.5186
# Epoch 32/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.4596 - loss: 1.2925 - val_accuracy: 0.2917 - val_loss: 1.5151
# Epoch 33/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5019 - loss: 1.2885 - val_accuracy: 0.2917 - val_loss: 1.5091
# Epoch 34/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.4659 - loss: 1.2925 - val_accuracy: 0.2917 - val_loss: 1.5030
# Epoch 35/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.4603 - loss: 1.2905 - val_accuracy: 0.2917 - val_loss: 1.4993
# Epoch 36/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4892 - loss: 1.2380 - val_accuracy: 0.2917 - val_loss: 1.4932
# Epoch 37/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.4592 - loss: 1.2690 - val_accuracy: 0.2917 - val_loss: 1.4883
# Epoch 38/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.4319 - loss: 1.2607 - val_accuracy: 0.2917 - val_loss: 1.4843
# Epoch 39/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.4459 - loss: 1.2165 - val_accuracy: 0.2917 - val_loss: 1.4805
# Epoch 40/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5009 - loss: 1.1572 - val_accuracy: 0.2917 - val_loss: 1.4759
# Epoch 41/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.4909 - loss: 1.2182 - val_accuracy: 0.2917 - val_loss: 1.4717
# Epoch 42/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5032 - loss: 1.1874 - val_accuracy: 0.2917 - val_loss: 1.4647
# Epoch 43/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.4738 - loss: 1.1660 - val_accuracy: 0.2917 - val_loss: 1.4607
# Epoch 44/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.4682 - loss: 1.1562 - val_accuracy: 0.2917 - val_loss: 1.4580
# Epoch 45/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5378 - loss: 1.1800 - val_accuracy: 0.2917 - val_loss: 1.4534
# Epoch 46/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5162 - loss: 1.1423 - val_accuracy: 0.2500 - val_loss: 1.4467
# Epoch 47/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4835 - loss: 1.1525 - val_accuracy: 0.2500 - val_loss: 1.4422
# Epoch 48/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5145 - loss: 1.1141 - val_accuracy: 0.2500 - val_loss: 1.4388
# Epoch 49/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.4755 - loss: 1.1644 - val_accuracy: 0.2500 - val_loss: 1.4350
# Epoch 50/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5168 - loss: 1.0912 - val_accuracy: 0.2500 - val_loss: 1.4314
# Epoch 51/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.5124 - loss: 1.1351 - val_accuracy: 0.2500 - val_loss: 1.4267
# Epoch 52/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5041 - loss: 1.0996 - val_accuracy: 0.2500 - val_loss: 1.4234
# Epoch 53/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5074 - loss: 1.1243 - val_accuracy: 0.2500 - val_loss: 1.4191
# Epoch 54/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5051 - loss: 1.0711 - val_accuracy: 0.2500 - val_loss: 1.4179
# Epoch 55/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5541 - loss: 1.0552 - val_accuracy: 0.2500 - val_loss: 1.4145
# Epoch 56/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5241 - loss: 1.0725 - val_accuracy: 0.2500 - val_loss: 1.4120
# Epoch 57/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5747 - loss: 1.0554 - val_accuracy: 0.2500 - val_loss: 1.4066
# Epoch 58/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5937 - loss: 1.0642 - val_accuracy: 0.2500 - val_loss: 1.4039
# Epoch 59/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5837 - loss: 1.0363 - val_accuracy: 0.2500 - val_loss: 1.4007
# Epoch 60/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5254 - loss: 1.0806 - val_accuracy: 0.2500 - val_loss: 1.3964
# Epoch 61/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.5231 - loss: 1.0550 - val_accuracy: 0.2500 - val_loss: 1.3934
# Epoch 62/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5887 - loss: 1.0244 - val_accuracy: 0.2500 - val_loss: 1.3874
# Epoch 63/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6037 - loss: 1.0538 - val_accuracy: 0.2500 - val_loss: 1.3842
# Epoch 64/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6137 - loss: 0.9810 - val_accuracy: 0.2500 - val_loss: 1.3810
# Epoch 65/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5893 - loss: 0.9853 - val_accuracy: 0.2500 - val_loss: 1.3798
# Epoch 66/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5493 - loss: 1.0202 - val_accuracy: 0.2500 - val_loss: 1.3794
# Epoch 67/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5983 - loss: 1.0077 - val_accuracy: 0.2500 - val_loss: 1.3766
# Epoch 68/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5910 - loss: 0.9837 - val_accuracy: 0.2500 - val_loss: 1.3748
# Epoch 69/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5339 - loss: 1.0331 - val_accuracy: 0.2500 - val_loss: 1.3732
# Epoch 70/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6223 - loss: 1.0249 - val_accuracy: 0.2917 - val_loss: 1.3710
# Epoch 71/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6285 - loss: 0.9812 - val_accuracy: 0.2500 - val_loss: 1.3664
# Epoch 72/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.6112 - loss: 1.0044 - val_accuracy: 0.2917 - val_loss: 1.3637
# Epoch 73/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6525 - loss: 0.9439 - val_accuracy: 0.2917 - val_loss: 1.3625
# Epoch 74/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5929 - loss: 0.9788 - val_accuracy: 0.2500 - val_loss: 1.3564
# Epoch 75/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5754 - loss: 0.9312 - val_accuracy: 0.2500 - val_loss: 1.3561
# Epoch 76/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6496 - loss: 0.9015 - val_accuracy: 0.2917 - val_loss: 1.3497
# Epoch 77/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5889 - loss: 0.9348 - val_accuracy: 0.2917 - val_loss: 1.3448
# Epoch 78/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6023 - loss: 0.9603 - val_accuracy: 0.2917 - val_loss: 1.3436
# Epoch 79/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6619 - loss: 0.9408 - val_accuracy: 0.2917 - val_loss: 1.3431
# Epoch 80/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6904 - loss: 0.9238 - val_accuracy: 0.2917 - val_loss: 1.3438
# Epoch 81/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6302 - loss: 0.9945 - val_accuracy: 0.2917 - val_loss: 1.3459
# Epoch 82/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.6215 - loss: 0.9421 - val_accuracy: 0.2917 - val_loss: 1.3411
# Epoch 83/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6958 - loss: 0.8673 - val_accuracy: 0.2917 - val_loss: 1.3414
# Epoch 84/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6844 - loss: 0.9616 - val_accuracy: 0.2917 - val_loss: 1.3393
# Epoch 85/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6598 - loss: 0.9544 - val_accuracy: 0.2917 - val_loss: 1.3377
# Epoch 86/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7484 - loss: 0.9173 - val_accuracy: 0.3750 - val_loss: 1.3339
# Epoch 87/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7163 - loss: 0.9335 - val_accuracy: 0.3333 - val_loss: 1.3315
# Epoch 88/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6744 - loss: 0.8890 - val_accuracy: 0.3750 - val_loss: 1.3327
# Epoch 89/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6821 - loss: 0.9433 - val_accuracy: 0.2917 - val_loss: 1.3349
# Epoch 90/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7609 - loss: 0.9026 - val_accuracy: 0.3333 - val_loss: 1.3303
# Epoch 91/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7473 - loss: 0.8318 - val_accuracy: 0.3333 - val_loss: 1.3287
# Epoch 92/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.7353 - loss: 0.9012 - val_accuracy: 0.2917 - val_loss: 1.3261
# Epoch 93/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6963 - loss: 0.9078 - val_accuracy: 0.2917 - val_loss: 1.3289
# Epoch 94/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7230 - loss: 0.8584 - val_accuracy: 0.2917 - val_loss: 1.3266
# Epoch 95/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7346 - loss: 0.8855 - val_accuracy: 0.2917 - val_loss: 1.3258
# Epoch 96/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7946 - loss: 0.8449 - val_accuracy: 0.2917 - val_loss: 1.3270
# Epoch 97/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7449 - loss: 0.8846 - val_accuracy: 0.3333 - val_loss: 1.3217
# Epoch 98/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7619 - loss: 0.8214 - val_accuracy: 0.3333 - val_loss: 1.3179
# Epoch 99/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7150 - loss: 0.8081 - val_accuracy: 0.2917 - val_loss: 1.3240
# Epoch 100/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7196 - loss: 0.8508 - val_accuracy: 0.2917 - val_loss: 1.3223
# Epoch 101/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7630 - loss: 0.8171 - val_accuracy: 0.2917 - val_loss: 1.3255
# Epoch 102/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7884 - loss: 0.8433 - val_accuracy: 0.3333 - val_loss: 1.3272
# Epoch 103/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7895 - loss: 0.8378 - val_accuracy: 0.3333 - val_loss: 1.3234
# Epoch 104/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7465 - loss: 0.8063 - val_accuracy: 0.3750 - val_loss: 1.3210
# Epoch 105/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7599 - loss: 0.8415 - val_accuracy: 0.3750 - val_loss: 1.3216
# Epoch 106/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7626 - loss: 0.7724 - val_accuracy: 0.3333 - val_loss: 1.3225
# Epoch 107/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7865 - loss: 0.7942 - val_accuracy: 0.3333 - val_loss: 1.3225
# Epoch 108/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8507 - loss: 0.8069 - val_accuracy: 0.3333 - val_loss: 1.3224
# Epoch 109/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7855 - loss: 0.7871 - val_accuracy: 0.3333 - val_loss: 1.3264
# Epoch 110/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8330 - loss: 0.8090 - val_accuracy: 0.3333 - val_loss: 1.3231
# Epoch 111/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8218 - loss: 0.8007 - val_accuracy: 0.3750 - val_loss: 1.3173
# Epoch 112/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.7699 - loss: 0.8084 - val_accuracy: 0.3750 - val_loss: 1.3187
# Epoch 113/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.7449 - loss: 0.7938 - val_accuracy: 0.3750 - val_loss: 1.3213
# Epoch 114/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.7665 - loss: 0.7670 - val_accuracy: 0.3333 - val_loss: 1.3259
# Epoch 115/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.7934 - loss: 0.8172 - val_accuracy: 0.3333 - val_loss: 1.3280
# Epoch 116/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8074 - loss: 0.7657 - val_accuracy: 0.3333 - val_loss: 1.3247
# Epoch 117/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8288 - loss: 0.7666 - val_accuracy: 0.3333 - val_loss: 1.3284
# Epoch 118/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8101 - loss: 0.7840 - val_accuracy: 0.3750 - val_loss: 1.3267
# Epoch 119/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8614 - loss: 0.7202 - val_accuracy: 0.3750 - val_loss: 1.3244
# Epoch 120/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.7865 - loss: 0.7404 - val_accuracy: 0.3333 - val_loss: 1.3362
# Epoch 121/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.8380 - loss: 0.7536 - val_accuracy: 0.3750 - val_loss: 1.3298
# Epoch 122/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.8118 - loss: 0.7291 - val_accuracy: 0.3750 - val_loss: 1.3277
# Epoch 123/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.8034 - loss: 0.7116 - val_accuracy: 0.3750 - val_loss: 1.3285
# Epoch 124/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.8338 - loss: 0.7214 - val_accuracy: 0.3750 - val_loss: 1.3284
# Epoch 125/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.8457 - loss: 0.7107 - val_accuracy: 0.3750 - val_loss: 1.3235
# Epoch 126/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.7795 - loss: 0.7722 - val_accuracy: 0.3750 - val_loss: 1.3322
# Epoch 127/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8330 - loss: 0.7315 - val_accuracy: 0.3750 - val_loss: 1.3313
# Epoch 128/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 117ms/step - accuracy: 0.8184 - loss: 0.7028 - val_accuracy: 0.3750 - val_loss: 1.3364
# Epoch 129/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8137 - loss: 0.7212 - val_accuracy: 0.3750 - val_loss: 1.3308
# Epoch 130/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7661 - loss: 0.7287 - val_accuracy: 0.3750 - val_loss: 1.3328
# Epoch 131/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8391 - loss: 0.6684 - val_accuracy: 0.3750 - val_loss: 1.3351
# Epoch 132/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8647 - loss: 0.6999 - val_accuracy: 0.3750 - val_loss: 1.3292
# Epoch 133/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.8284 - loss: 0.6920 - val_accuracy: 0.3750 - val_loss: 1.3317
# Epoch 134/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8222 - loss: 0.6589 - val_accuracy: 0.3750 - val_loss: 1.3391
# Epoch 135/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8430 - loss: 0.6883 - val_accuracy: 0.3750 - val_loss: 1.3282
# Epoch 136/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.7818 - loss: 0.7074 - val_accuracy: 0.3750 - val_loss: 1.3322
# Epoch 137/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8107 - loss: 0.7078 - val_accuracy: 0.3750 - val_loss: 1.3383
# Epoch 138/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8430 - loss: 0.6989 - val_accuracy: 0.3750 - val_loss: 1.3435
# Epoch 139/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8297 - loss: 0.6846 - val_accuracy: 0.4167 - val_loss: 1.3409
# Epoch 140/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8347 - loss: 0.7035 - val_accuracy: 0.4167 - val_loss: 1.3376
# Epoch 141/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.8524 - loss: 0.6484 - val_accuracy: 0.3750 - val_loss: 1.3494
# Epoch 142/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8191 - loss: 0.6898 - val_accuracy: 0.4167 - val_loss: 1.3380
# Epoch 143/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8018 - loss: 0.6585 - val_accuracy: 0.4167 - val_loss: 1.3435
# Epoch 144/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8347 - loss: 0.6615 - val_accuracy: 0.4167 - val_loss: 1.3434
# Epoch 145/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.8414 - loss: 0.6466 - val_accuracy: 0.4167 - val_loss: 1.3306
# Epoch 146/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 160ms/step - accuracy: 0.7988 - loss: 0.6258 - val_accuracy: 0.4167 - val_loss: 1.3338
# Epoch 147/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.8641 - loss: 0.6570 - val_accuracy: 0.4167 - val_loss: 1.3471
# Epoch 148/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8676 - loss: 0.6384 - val_accuracy: 0.3750 - val_loss: 1.3602
# Epoch 149/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8670 - loss: 0.6437 - val_accuracy: 0.4167 - val_loss: 1.3458
# Epoch 150/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8803 - loss: 0.6093 - val_accuracy: 0.4167 - val_loss: 1.3494
# Epoch 151/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.8680 - loss: 0.6109 - val_accuracy: 0.4167 - val_loss: 1.3620
# Epoch 152/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.8153 - loss: 0.6590 - val_accuracy: 0.4167 - val_loss: 1.3470
# Epoch 153/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8424 - loss: 0.5974 - val_accuracy: 0.4167 - val_loss: 1.3525
# Epoch 154/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8576 - loss: 0.6226 - val_accuracy: 0.4167 - val_loss: 1.3589
# Epoch 155/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8943 - loss: 0.6418 - val_accuracy: 0.4167 - val_loss: 1.3544
# Epoch 156/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8014 - loss: 0.6551 - val_accuracy: 0.4167 - val_loss: 1.3667
# Epoch 157/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8876 - loss: 0.5718 - val_accuracy: 0.4167 - val_loss: 1.3648
# Epoch 158/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8676 - loss: 0.5954 - val_accuracy: 0.4167 - val_loss: 1.3657
# Epoch 159/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9199 - loss: 0.5859 - val_accuracy: 0.4167 - val_loss: 1.3656
# Epoch 160/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8287 - loss: 0.6019 - val_accuracy: 0.4167 - val_loss: 1.3763
# Epoch 161/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8783 - loss: 0.6065 - val_accuracy: 0.4167 - val_loss: 1.3793
# Epoch 162/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8783 - loss: 0.5880 - val_accuracy: 0.4167 - val_loss: 1.3653
# Epoch 163/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8457 - loss: 0.5717 - val_accuracy: 0.4167 - val_loss: 1.3896
# Epoch 164/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8410 - loss: 0.6178 - val_accuracy: 0.4167 - val_loss: 1.3918
# Epoch 165/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8533 - loss: 0.6422 - val_accuracy: 0.4167 - val_loss: 1.3795
# Epoch 166/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8803 - loss: 0.5757 - val_accuracy: 0.4167 - val_loss: 1.3960
# Epoch 167/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8783 - loss: 0.5737 - val_accuracy: 0.4167 - val_loss: 1.3855
# Epoch 168/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8666 - loss: 0.5741 - val_accuracy: 0.4167 - val_loss: 1.3921
# Epoch 169/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9043 - loss: 0.4915 - val_accuracy: 0.4167 - val_loss: 1.3924
# Epoch 170/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8693 - loss: 0.5758 - val_accuracy: 0.4167 - val_loss: 1.3935
# Epoch 171/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9216 - loss: 0.5717 - val_accuracy: 0.4167 - val_loss: 1.3940
# Epoch 172/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8387 - loss: 0.5856 - val_accuracy: 0.4167 - val_loss: 1.4059
# Epoch 173/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.8720 - loss: 0.5444 - val_accuracy: 0.4167 - val_loss: 1.4156
# Epoch 174/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8676 - loss: 0.5351 - val_accuracy: 0.4167 - val_loss: 1.4076
# Epoch 175/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8933 - loss: 0.5463 - val_accuracy: 0.4167 - val_loss: 1.4072
# Epoch 176/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.8576 - loss: 0.5688 - val_accuracy: 0.4167 - val_loss: 1.4214
# Epoch 177/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.9066 - loss: 0.5159 - val_accuracy: 0.4167 - val_loss: 1.4186
# Epoch 178/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8916 - loss: 0.5343 - val_accuracy: 0.4167 - val_loss: 1.4145
# Epoch 179/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8616 - loss: 0.5451 - val_accuracy: 0.4167 - val_loss: 1.4268
# Epoch 180/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.8916 - loss: 0.5167 - val_accuracy: 0.4167 - val_loss: 1.4326
# Epoch 181/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9056 - loss: 0.5108 - val_accuracy: 0.4167 - val_loss: 1.4246
# Epoch 182/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8899 - loss: 0.5259 - val_accuracy: 0.4167 - val_loss: 1.4273
# Epoch 183/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9133 - loss: 0.4902 - val_accuracy: 0.4167 - val_loss: 1.4598
# Epoch 184/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.8766 - loss: 0.5192 - val_accuracy: 0.4167 - val_loss: 1.4665
# Epoch 185/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.8749 - loss: 0.5254 - val_accuracy: 0.4167 - val_loss: 1.4444
# Epoch 186/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8966 - loss: 0.5080 - val_accuracy: 0.4167 - val_loss: 1.4549
# Epoch 187/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.8866 - loss: 0.5115 - val_accuracy: 0.4167 - val_loss: 1.4629
# Epoch 188/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.8776 - loss: 0.4878 - val_accuracy: 0.4167 - val_loss: 1.4639
# Epoch 189/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.8983 - loss: 0.5014 - val_accuracy: 0.4167 - val_loss: 1.4653
# Epoch 190/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9006 - loss: 0.5011 - val_accuracy: 0.4167 - val_loss: 1.4771
# Epoch 191/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9049 - loss: 0.4612 - val_accuracy: 0.4167 - val_loss: 1.4906
# Epoch 192/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8949 - loss: 0.4784 - val_accuracy: 0.4167 - val_loss: 1.4971
# Epoch 193/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8872 - loss: 0.5273 - val_accuracy: 0.4167 - val_loss: 1.5041
# Epoch 194/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9039 - loss: 0.4731 - val_accuracy: 0.4167 - val_loss: 1.5044
# Epoch 195/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8733 - loss: 0.5087 - val_accuracy: 0.4167 - val_loss: 1.5160
# Epoch 196/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8716 - loss: 0.5022 - val_accuracy: 0.4167 - val_loss: 1.4996
# Epoch 197/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8533 - loss: 0.5283 - val_accuracy: 0.4167 - val_loss: 1.4968
# Epoch 198/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.9049 - loss: 0.4374 - val_accuracy: 0.4167 - val_loss: 1.4890
# Epoch 199/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8833 - loss: 0.4997 - val_accuracy: 0.4167 - val_loss: 1.4894
# Epoch 200/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8583 - loss: 0.5005 - val_accuracy: 0.4167 - val_loss: 1.5266
# Epoch 201/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8949 - loss: 0.4632 - val_accuracy: 0.4167 - val_loss: 1.5339
# Epoch 202/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8566 - loss: 0.4940 - val_accuracy: 0.4167 - val_loss: 1.5302
# Epoch 203/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8972 - loss: 0.4463 - val_accuracy: 0.4167 - val_loss: 1.5289
# Epoch 204/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9039 - loss: 0.4443 - val_accuracy: 0.4167 - val_loss: 1.5390
# Epoch 205/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9006 - loss: 0.4479 - val_accuracy: 0.4167 - val_loss: 1.5153
# Epoch 206/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8766 - loss: 0.4417 - val_accuracy: 0.4167 - val_loss: 1.5538
# Epoch 207/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8995 - loss: 0.4597 - val_accuracy: 0.4167 - val_loss: 1.5316
# Epoch 208/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9099 - loss: 0.4339 - val_accuracy: 0.4167 - val_loss: 1.5530
# Epoch 209/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9145 - loss: 0.4620 - val_accuracy: 0.4167 - val_loss: 1.5453
# Epoch 210/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9145 - loss: 0.4378 - val_accuracy: 0.4167 - val_loss: 1.5459
# Epoch 211/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9279 - loss: 0.4025 - val_accuracy: 0.4583 - val_loss: 1.5257
# Epoch 212/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8622 - loss: 0.4840 - val_accuracy: 0.4583 - val_loss: 1.5516
# Epoch 213/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8522 - loss: 0.4656 - val_accuracy: 0.4583 - val_loss: 1.5536
# Epoch 214/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9072 - loss: 0.4128 - val_accuracy: 0.4167 - val_loss: 1.5598
# Epoch 215/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9179 - loss: 0.3996 - val_accuracy: 0.4167 - val_loss: 1.5738
# Epoch 216/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9206 - loss: 0.4157 - val_accuracy: 0.4167 - val_loss: 1.5823
# Epoch 217/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9379 - loss: 0.4024 - val_accuracy: 0.4583 - val_loss: 1.5641
# Epoch 218/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8906 - loss: 0.4252 - val_accuracy: 0.4167 - val_loss: 1.6110
# Epoch 219/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8906 - loss: 0.4503 - val_accuracy: 0.4167 - val_loss: 1.6151
# Epoch 220/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9162 - loss: 0.4036 - val_accuracy: 0.4167 - val_loss: 1.6143
# Epoch 221/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9418 - loss: 0.4015 - val_accuracy: 0.4167 - val_loss: 1.6056
# Epoch 222/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8972 - loss: 0.4239 - val_accuracy: 0.4167 - val_loss: 1.6312
# Epoch 223/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9245 - loss: 0.3938 - val_accuracy: 0.4583 - val_loss: 1.6038
# Epoch 224/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9235 - loss: 0.4203 - val_accuracy: 0.4167 - val_loss: 1.6361
# Epoch 225/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9302 - loss: 0.4117 - val_accuracy: 0.4167 - val_loss: 1.6573
# Epoch 226/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9152 - loss: 0.4274 - val_accuracy: 0.4167 - val_loss: 1.6371
# Epoch 227/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9468 - loss: 0.3679 - val_accuracy: 0.4583 - val_loss: 1.6298
# Epoch 228/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9112 - loss: 0.4060 - val_accuracy: 0.4583 - val_loss: 1.6385
# Epoch 229/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9429 - loss: 0.3743 - val_accuracy: 0.4167 - val_loss: 1.6794
# Epoch 230/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9335 - loss: 0.3710 - val_accuracy: 0.4583 - val_loss: 1.6680
# Epoch 231/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9329 - loss: 0.3856 - val_accuracy: 0.4583 - val_loss: 1.6359
# Epoch 232/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8995 - loss: 0.3755 - val_accuracy: 0.4583 - val_loss: 1.6436
# Epoch 233/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9302 - loss: 0.3812 - val_accuracy: 0.4583 - val_loss: 1.6597
# Epoch 234/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9395 - loss: 0.3696 - val_accuracy: 0.4583 - val_loss: 1.6715
# Epoch 235/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9385 - loss: 0.3612 - val_accuracy: 0.4583 - val_loss: 1.6624
# Epoch 236/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9062 - loss: 0.3855 - val_accuracy: 0.5000 - val_loss: 1.7096
# Epoch 237/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9391 - loss: 0.3772 - val_accuracy: 0.5000 - val_loss: 1.6757
# Epoch 238/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9368 - loss: 0.3502 - val_accuracy: 0.4583 - val_loss: 1.6845
# Epoch 239/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9102 - loss: 0.4005 - val_accuracy: 0.5000 - val_loss: 1.7276
# Epoch 240/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9608 - loss: 0.3532 - val_accuracy: 0.4583 - val_loss: 1.7205
# Epoch 241/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9202 - loss: 0.3797 - val_accuracy: 0.5000 - val_loss: 1.7202
# Epoch 242/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9302 - loss: 0.3681 - val_accuracy: 0.5000 - val_loss: 1.7192
# Epoch 243/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9418 - loss: 0.3539 - val_accuracy: 0.4167 - val_loss: 1.7358
# Epoch 244/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9002 - loss: 0.4028 - val_accuracy: 0.4583 - val_loss: 1.7465
# Epoch 245/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9241 - loss: 0.3642 - val_accuracy: 0.4583 - val_loss: 1.7564
# Epoch 246/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9475 - loss: 0.3741 - val_accuracy: 0.5000 - val_loss: 1.7393
# Epoch 247/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.9325 - loss: 0.3531 - val_accuracy: 0.5000 - val_loss: 1.7500
# Epoch 248/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 199ms/step - accuracy: 0.9425 - loss: 0.3481 - val_accuracy: 0.4583 - val_loss: 1.7553
# Epoch 249/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.9441 - loss: 0.3326 - val_accuracy: 0.4583 - val_loss: 1.7385
# Epoch 250/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.9341 - loss: 0.3438 - val_accuracy: 0.4583 - val_loss: 1.7688
# Epoch 251/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.9575 - loss: 0.3368 - val_accuracy: 0.4167 - val_loss: 1.7969
# Epoch 252/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.9325 - loss: 0.3388 - val_accuracy: 0.4167 - val_loss: 1.7662
# Epoch 253/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9441 - loss: 0.3503 - val_accuracy: 0.4167 - val_loss: 1.7861
# Epoch 254/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9141 - loss: 0.3646 - val_accuracy: 0.5000 - val_loss: 1.7940
# Epoch 255/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9191 - loss: 0.3429 - val_accuracy: 0.4583 - val_loss: 1.7721
# Epoch 256/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9291 - loss: 0.3465 - val_accuracy: 0.4583 - val_loss: 1.7883
# Epoch 257/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9141 - loss: 0.3586 - val_accuracy: 0.4583 - val_loss: 1.8265
# Epoch 258/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9425 - loss: 0.3230 - val_accuracy: 0.4583 - val_loss: 1.8114
# Epoch 259/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9385 - loss: 0.3164 - val_accuracy: 0.4583 - val_loss: 1.8872
# Epoch 260/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9291 - loss: 0.3673 - val_accuracy: 0.5000 - val_loss: 1.8537
# Epoch 261/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.9441 - loss: 0.3312 - val_accuracy: 0.5000 - val_loss: 1.8525
# Epoch 262/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9491 - loss: 0.2950 - val_accuracy: 0.4167 - val_loss: 1.8529
# Epoch 263/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.9341 - loss: 0.3067 - val_accuracy: 0.5000 - val_loss: 1.8928
# Epoch 264/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9675 - loss: 0.2919 - val_accuracy: 0.4583 - val_loss: 1.8210
# Epoch 265/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8995 - loss: 0.3134 - val_accuracy: 0.5000 - val_loss: 1.8636
# Epoch 266/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9441 - loss: 0.3043 - val_accuracy: 0.5000 - val_loss: 1.8695
# Epoch 267/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9714 - loss: 0.2811 - val_accuracy: 0.4583 - val_loss: 1.8489
# Epoch 268/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9391 - loss: 0.3078 - val_accuracy: 0.4583 - val_loss: 1.8959
# Epoch 269/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9491 - loss: 0.2997 - val_accuracy: 0.4583 - val_loss: 1.9068
# Epoch 270/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9714 - loss: 0.2858 - val_accuracy: 0.4583 - val_loss: 1.8537
# Epoch 271/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9325 - loss: 0.3086 - val_accuracy: 0.4583 - val_loss: 1.8738
# Epoch 272/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9691 - loss: 0.2717 - val_accuracy: 0.4583 - val_loss: 1.8635
# Epoch 273/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9691 - loss: 0.2621 - val_accuracy: 0.4583 - val_loss: 1.8661
# Epoch 274/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8952 - loss: 0.3236 - val_accuracy: 0.4583 - val_loss: 1.9283
# Epoch 275/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9658 - loss: 0.2628 - val_accuracy: 0.4167 - val_loss: 1.8868
# Epoch 276/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9002 - loss: 0.3198 - val_accuracy: 0.5000 - val_loss: 1.9124
# Epoch 277/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9508 - loss: 0.2820 - val_accuracy: 0.5000 - val_loss: 1.9147
# Epoch 278/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9341 - loss: 0.2760 - val_accuracy: 0.5000 - val_loss: 1.9307
# Epoch 279/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9491 - loss: 0.2565 - val_accuracy: 0.5000 - val_loss: 1.9402
# Epoch 280/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9475 - loss: 0.2614 - val_accuracy: 0.4167 - val_loss: 1.8907
# Epoch 281/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9335 - loss: 0.2739 - val_accuracy: 0.4167 - val_loss: 1.9577
# Epoch 282/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9581 - loss: 0.2711 - val_accuracy: 0.4167 - val_loss: 1.9842
# Epoch 283/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9431 - loss: 0.3009 - val_accuracy: 0.4167 - val_loss: 1.9713
# Epoch 284/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9564 - loss: 0.2557 - val_accuracy: 0.5000 - val_loss: 1.9473
# Epoch 285/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9491 - loss: 0.2537 - val_accuracy: 0.4583 - val_loss: 1.9901
# Epoch 286/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9748 - loss: 0.2410 - val_accuracy: 0.4583 - val_loss: 1.9420
# Epoch 287/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9714 - loss: 0.2438 - val_accuracy: 0.5000 - val_loss: 1.9773
# Epoch 288/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9425 - loss: 0.2637 - val_accuracy: 0.5000 - val_loss: 1.9813
# Epoch 289/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.9441 - loss: 0.2792 - val_accuracy: 0.5000 - val_loss: 1.9975
# Epoch 290/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9141 - loss: 0.2649 - val_accuracy: 0.4583 - val_loss: 1.9998
# Epoch 291/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9481 - loss: 0.2565 - val_accuracy: 0.4583 - val_loss: 2.0566
# Epoch 292/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9631 - loss: 0.2430 - val_accuracy: 0.4583 - val_loss: 2.0400
# Epoch 293/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9531 - loss: 0.2663 - val_accuracy: 0.4583 - val_loss: 2.0437
# Epoch 294/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9664 - loss: 0.2222 - val_accuracy: 0.4583 - val_loss: 2.0430
# Epoch 295/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9648 - loss: 0.2182 - val_accuracy: 0.4167 - val_loss: 2.0146
# Epoch 296/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9225 - loss: 0.2439 - val_accuracy: 0.4583 - val_loss: 2.0791
# Epoch 297/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9681 - loss: 0.2197 - val_accuracy: 0.4583 - val_loss: 2.0715
# Epoch 298/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9714 - loss: 0.2230 - val_accuracy: 0.4583 - val_loss: 2.0387
# Epoch 299/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9368 - loss: 0.2423 - val_accuracy: 0.4583 - val_loss: 2.0958
# Epoch 300/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9854 - loss: 0.2374 - val_accuracy: 0.4583 - val_loss: 2.0743

# %% [markdown]
# ### Activation Functions and Output Layer Design

# %% [markdown]
# In the hidden layers, the ReLU (Rectified Linear Unit) activation function was used. ReLU was chosen because it introduces nonlinearity while remaining computationally efficient and helps prevent the vanishing gradient problem that can occur with sigmoid or tanh activations. Given the moderate depth of the network (128→64→64→32), ReLU supports stable gradient flow during training and allows the model to learn nonlinear relationships between socioeconomic indicators and happiness categories.
#
# Softmax was used in the final layer because the task is multi-class classification with five mutually exclusive happiness categories. The final layer therefore contains five neurons, one for each class. Softmax converts the output logits into a probability distribution that sums to 1, enabling the model to assign class probabilities and select the category with the highest predicted likelihood. This activation is appropriate when using categorical cross-entropy loss and aligns with the structure of the one-hot encoded target labels.

# %% [markdown]
# ### Training Duration and Epoch Selection (300)

# %% [markdown]
# Training for 300 epochs is not necessarily optimal and depends on validation performance. In small tabular datasets such as this one, long training durations increase the risk of overfitting. If validation accuracy plateaus early or begins to decline while training accuracy continues to increase, this indicates that the model is memorizing the training data rather than improving generalization.
#
# Given the relatively small sample size and moderate model complexity, it is likely that the network converges well before 300 epochs. Training longer beyond the point of convergence does not improve test performance and may worsen it due to overfitting. A better approach would be to monitor validation loss and implement early stopping, which automatically halts training when performance stops improving. This ensures efficient training while preserving generalization.
#
# Therefore, 300 epochs may be acceptable as an upper bound, but the decision should be guided by validation metrics rather than a fixed number of epochs.

# %% [markdown]
# ### Loss Function and Optimization Strategy

# %% [markdown]
# loss='categorical_crossentropy' was used because this is a multi-class classification problem with mutually exclusive categories and one-hot encoded labels. Categorical cross-entropy measures the divergence between the predicted probability distribution (produced by the softmax output layer) and the true class distribution. Since the final layer uses softmax and the labels are one-hot encoded, categorical cross-entropy is the mathematically appropriate loss function for this setting.
#
# optimizer='sgd' (Stochastic Gradient Descent) was used because it is a standard gradient-based optimization method that updates model weights iteratively using mini-batches. SGD is simple, stable, and often effective when learning rates are properly tuned. However, plain SGD can converge slowly and may require careful learning rate selection to achieve strong performance.
#
# Given the moderate dataset size and network depth, switching to an adaptive optimizer such as Adam could improve convergence speed and stability. Adam automatically adjusts learning rates for each parameter, often reaching good solutions faster and with less manual tuning. Therefore, while categorical cross-entropy is appropriate and should not be changed, replacing SGD with Adam would likely improve training efficiency and potentially final validation performance.

# %% [markdown]
# ### Plot Training Curves
#
# In this section, the model’s training history is used to plot learning curves showing training and validation loss and accuracy across epochs. These curves help evaluate how the model learns over time and reveal potential issues such as overfitting or underfitting.

# %%
## Your code to plot training and validation curves in a single plot (Make changes in the model cell to be able to do this) : TODO

# Single-plot learning curves
import matplotlib.pyplot as plt

hist = history.history
epochs = range(1, len(hist["loss"]) + 1)

fig, ax1 = plt.subplots(figsize=(10,6))

# Loss on left axis
ax1.plot(epochs, hist["loss"], label="Train Loss")
ax1.plot(epochs, hist["val_loss"], label="Val Loss")
ax1.set_xlabel("Epoch")
ax1.set_ylabel("Loss")

# Accuracy on right axis
ax2 = ax1.twinx()
ax2.plot(epochs, hist["accuracy"], label="Train Accuracy")
ax2.plot(epochs, hist["val_accuracy"], label="Val Accuracy")
ax2.set_ylabel("Accuracy")

# Combined legend
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines1 + lines2, labels1 + labels2, loc="center right")

plt.title("Training and Validation Curves (Loss and Accuracy)")
plt.tight_layout()
plt.show()

# %%
#-- Generate predicted y values

from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import numpy as np

# Generate predicted column index values
prediction_column_index = np.argmax(keras_model.predict(X_test_nn), axis=1)

# Extract correct prediction labels
label_names = y_train.astype('category').cat.categories
prediction_labels = [label_names[i] for i in prediction_column_index]

# Show model performance
print("Neural Network Test Accuracy:", accuracy_score(y_test, prediction_labels))

print("\nClassification Report:\n")
print(classification_report(y_test, prediction_labels))

print("\nConfusion Matrix:\n")
print(confusion_matrix(y_test, prediction_labels))
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# Neural Network Test Accuracy: 0.6190476190476191
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#      Average       0.67      0.50      0.57         8
#         High       0.60      0.75      0.67         8
#          Low       0.50      0.50      0.50         8
#    Very High       0.88      0.78      0.82         9
#     Very Low       0.50      0.56      0.53         9
#
#     accuracy                           0.62        42
#    macro avg       0.63      0.62      0.62        42
# weighted avg       0.63      0.62      0.62        42
#
#
# Confusion Matrix:
#
# [[4 2 0 0 2]
#  [1 6 0 1 0]
#  [1 0 4 0 3]
#  [0 2 0 7 0]
#  [0 0 4 0 5]]

# %% [markdown]
# ### Regularization: Dropout and Batch Normalization
#
# Regularization techniques such as Dropout and Batch Normalization are applied to the neural network to improve generalization and reduce overfitting. Model performance is compared before and after applying these techniques by examining changes in training and validation loss and accuracy.

# %%
# Difine Regularized Neural Network
from keras.models import Sequential
from keras.layers import Dense, Dropout, BatchNormalization
from keras.optimizers import Adam

# Build regularized model
keras_model_reg = Sequential([
    Dense(128, activation='relu', input_shape=(feature_count,)),
    BatchNormalization(),
    Dropout(0.3),

    Dense(64, activation='relu'),
    BatchNormalization(),
    Dropout(0.3),

    Dense(64, activation='relu'),
    BatchNormalization(),
    Dropout(0.2),

    Dense(32, activation='relu'),
    BatchNormalization(),

    Dense(num_classes, activation='softmax')
])

keras_model_reg.compile(
    loss='categorical_crossentropy',
    optimizer=Adam(learning_rate=0.001),
    metrics=['accuracy']
)

history_reg = keras_model_reg.fit(
    X_train_nn, y_train_onehot,
    batch_size=20,
    epochs=300,
    validation_split=0.25,
    verbose=1
)

# Evaluate Regularized Model
test_loss_reg, test_acc_reg = keras_model_reg.evaluate(X_test_nn, y_test_onehot, verbose=0)
print("Regularized NN Test Accuracy:", test_acc_reg)

# Plot Before vs. After Regularization
import matplotlib.pyplot as plt

plt.figure(figsize=(12,5))

# Accuracy comparison
plt.subplot(1,2,1)
plt.plot(history.history['val_accuracy'], label='Val Acc (No Reg)')
plt.plot(history_reg.history['val_accuracy'], label='Val Acc (Reg)')
plt.title("Validation Accuracy Comparison")
plt.legend()

# Loss comparison
plt.subplot(1,2,2)
plt.plot(history.history['val_loss'], label='Val Loss (No Reg)')
plt.plot(history_reg.history['val_loss'], label='Val Loss (Reg)')
plt.title("Validation Loss Comparison")
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 11s 125ms/step - accuracy: 0.2408 - loss: 2.2696 - val_accuracy: 0.1667 - val_loss: 1.5798
# Epoch 2/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.2185 - loss: 1.9034 - val_accuracy: 0.2500 - val_loss: 1.5487
# Epoch 3/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.4334 - loss: 1.4829 - val_accuracy: 0.3333 - val_loss: 1.5234
# Epoch 4/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.4819 - loss: 1.5100 - val_accuracy: 0.4583 - val_loss: 1.5034
# Epoch 5/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.4469 - loss: 1.4575 - val_accuracy: 0.4167 - val_loss: 1.4894
# Epoch 6/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.4576 - loss: 1.4187 - val_accuracy: 0.5000 - val_loss: 1.4742
# Epoch 7/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.4392 - loss: 1.5167 - val_accuracy: 0.5417 - val_loss: 1.4565
# Epoch 8/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6193 - loss: 1.0217 - val_accuracy: 0.5417 - val_loss: 1.4418
# Epoch 9/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.4765 - loss: 1.3775 - val_accuracy: 0.5417 - val_loss: 1.4316
# Epoch 10/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.4403 - loss: 1.3608 - val_accuracy: 0.5000 - val_loss: 1.4218
# Epoch 11/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.4257 - loss: 1.3215 - val_accuracy: 0.5000 - val_loss: 1.4127
# Epoch 12/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5854 - loss: 1.0834 - val_accuracy: 0.5000 - val_loss: 1.4016
# Epoch 13/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6321 - loss: 0.8913 - val_accuracy: 0.4583 - val_loss: 1.3920
# Epoch 14/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5985 - loss: 0.9442 - val_accuracy: 0.4583 - val_loss: 1.3835
# Epoch 15/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6102 - loss: 1.0242 - val_accuracy: 0.5417 - val_loss: 1.3771
# Epoch 16/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6844 - loss: 0.8608 - val_accuracy: 0.5417 - val_loss: 1.3678
# Epoch 17/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6612 - loss: 0.8836 - val_accuracy: 0.5833 - val_loss: 1.3616
# Epoch 18/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.5627 - loss: 1.0602 - val_accuracy: 0.5417 - val_loss: 1.3544
# Epoch 19/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6539 - loss: 0.8384 - val_accuracy: 0.5417 - val_loss: 1.3473
# Epoch 20/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6321 - loss: 0.8451 - val_accuracy: 0.5833 - val_loss: 1.3432
# Epoch 21/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7190 - loss: 0.7168 - val_accuracy: 0.5417 - val_loss: 1.3362
# Epoch 22/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6531 - loss: 0.9564 - val_accuracy: 0.5417 - val_loss: 1.3294
# Epoch 23/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6689 - loss: 0.7962 - val_accuracy: 0.5417 - val_loss: 1.3166
# Epoch 24/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.6631 - loss: 0.7369 - val_accuracy: 0.5833 - val_loss: 1.3074
# Epoch 25/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6323 - loss: 0.8269 - val_accuracy: 0.5417 - val_loss: 1.3026
# Epoch 26/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7446 - loss: 0.8222 - val_accuracy: 0.5000 - val_loss: 1.2974
# Epoch 27/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5919 - loss: 0.9831 - val_accuracy: 0.4583 - val_loss: 1.2940
# Epoch 28/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7221 - loss: 0.7594 - val_accuracy: 0.4583 - val_loss: 1.2902
# Epoch 29/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6827 - loss: 0.9431 - val_accuracy: 0.4583 - val_loss: 1.2849
# Epoch 30/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7094 - loss: 0.7288 - val_accuracy: 0.4583 - val_loss: 1.2719
# Epoch 31/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5904 - loss: 1.0301 - val_accuracy: 0.4583 - val_loss: 1.2568
# Epoch 32/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8138 - loss: 0.6092 - val_accuracy: 0.4583 - val_loss: 1.2498
# Epoch 33/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7407 - loss: 0.7835 - val_accuracy: 0.5000 - val_loss: 1.2398
# Epoch 34/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.7203 - loss: 0.6855 - val_accuracy: 0.5000 - val_loss: 1.2328
# Epoch 35/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6894 - loss: 0.7884 - val_accuracy: 0.4167 - val_loss: 1.2269
# Epoch 36/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.6715 - loss: 0.7164 - val_accuracy: 0.4583 - val_loss: 1.2204
# Epoch 37/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.7653 - loss: 0.6013 - val_accuracy: 0.4583 - val_loss: 1.2141
# Epoch 38/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.7859 - loss: 0.6635 - val_accuracy: 0.4583 - val_loss: 1.2066
# Epoch 39/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6688 - loss: 0.8859 - val_accuracy: 0.4583 - val_loss: 1.2004
# Epoch 40/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.7177 - loss: 0.7289 - val_accuracy: 0.5417 - val_loss: 1.1931
# Epoch 41/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.7586 - loss: 0.7273 - val_accuracy: 0.4583 - val_loss: 1.1887
# Epoch 42/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.7469 - loss: 0.6764 - val_accuracy: 0.4167 - val_loss: 1.1828
# Epoch 43/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.6904 - loss: 0.6271 - val_accuracy: 0.4167 - val_loss: 1.1787
# Epoch 44/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.7240 - loss: 0.6303 - val_accuracy: 0.4583 - val_loss: 1.1800
# Epoch 45/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6903 - loss: 0.8069 - val_accuracy: 0.4583 - val_loss: 1.1836
# Epoch 46/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.7676 - loss: 0.6584 - val_accuracy: 0.4583 - val_loss: 1.1837
# Epoch 47/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.7715 - loss: 0.7905 - val_accuracy: 0.4583 - val_loss: 1.1879
# Epoch 48/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.7246 - loss: 0.7227 - val_accuracy: 0.4167 - val_loss: 1.1923
# Epoch 49/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7915 - loss: 0.4892 - val_accuracy: 0.4167 - val_loss: 1.1930
# Epoch 50/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.8178 - loss: 0.4781 - val_accuracy: 0.4167 - val_loss: 1.1918
# Epoch 51/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8130 - loss: 0.5740 - val_accuracy: 0.4167 - val_loss: 1.1974
# Epoch 52/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8787 - loss: 0.4675 - val_accuracy: 0.4583 - val_loss: 1.1992
# Epoch 53/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.8178 - loss: 0.5116 - val_accuracy: 0.4583 - val_loss: 1.1994
# Epoch 54/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8041 - loss: 0.6200 - val_accuracy: 0.4583 - val_loss: 1.1970
# Epoch 55/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.8065 - loss: 0.5253 - val_accuracy: 0.4583 - val_loss: 1.1950
# Epoch 56/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8797 - loss: 0.4573 - val_accuracy: 0.4583 - val_loss: 1.2011
# Epoch 57/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8174 - loss: 0.4697 - val_accuracy: 0.5000 - val_loss: 1.2094
# Epoch 58/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8947 - loss: 0.3532 - val_accuracy: 0.5000 - val_loss: 1.2211
# Epoch 59/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8101 - loss: 0.5217 - val_accuracy: 0.4583 - val_loss: 1.2382
# Epoch 60/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8095 - loss: 0.4731 - val_accuracy: 0.4583 - val_loss: 1.2516
# Epoch 61/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8118 - loss: 0.6001 - val_accuracy: 0.4583 - val_loss: 1.2684
# Epoch 62/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8022 - loss: 0.5566 - val_accuracy: 0.4583 - val_loss: 1.2820
# Epoch 63/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8257 - loss: 0.4366 - val_accuracy: 0.4583 - val_loss: 1.2876
# Epoch 64/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8192 - loss: 0.5446 - val_accuracy: 0.4583 - val_loss: 1.2968
# Epoch 65/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.7861 - loss: 0.4977 - val_accuracy: 0.4583 - val_loss: 1.3035
# Epoch 66/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7788 - loss: 0.5019 - val_accuracy: 0.4583 - val_loss: 1.3163
# Epoch 67/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8451 - loss: 0.4810 - val_accuracy: 0.4167 - val_loss: 1.3192
# Epoch 68/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9106 - loss: 0.3453 - val_accuracy: 0.4167 - val_loss: 1.3238
# Epoch 69/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8753 - loss: 0.4290 - val_accuracy: 0.4167 - val_loss: 1.3241
# Epoch 70/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7213 - loss: 0.5412 - val_accuracy: 0.4167 - val_loss: 1.3304
# Epoch 71/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8174 - loss: 0.5053 - val_accuracy: 0.4167 - val_loss: 1.3340
# Epoch 72/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8810 - loss: 0.4265 - val_accuracy: 0.4167 - val_loss: 1.3408
# Epoch 73/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8724 - loss: 0.3665 - val_accuracy: 0.4167 - val_loss: 1.3416
# Epoch 74/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8816 - loss: 0.3999 - val_accuracy: 0.4583 - val_loss: 1.3453
# Epoch 75/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8447 - loss: 0.4501 - val_accuracy: 0.4583 - val_loss: 1.3511
# Epoch 76/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8843 - loss: 0.3920 - val_accuracy: 0.4583 - val_loss: 1.3610
# Epoch 77/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7901 - loss: 0.5112 - val_accuracy: 0.4583 - val_loss: 1.3640
# Epoch 78/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8264 - loss: 0.4139 - val_accuracy: 0.4583 - val_loss: 1.3692
# Epoch 79/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8707 - loss: 0.3930 - val_accuracy: 0.4583 - val_loss: 1.3863
# Epoch 80/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9039 - loss: 0.3543 - val_accuracy: 0.4167 - val_loss: 1.4076
# Epoch 81/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8495 - loss: 0.4101 - val_accuracy: 0.4167 - val_loss: 1.4281
# Epoch 82/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8055 - loss: 0.4348 - val_accuracy: 0.3750 - val_loss: 1.4530
# Epoch 83/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8470 - loss: 0.3610 - val_accuracy: 0.3750 - val_loss: 1.4793
# Epoch 84/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8876 - loss: 0.3679 - val_accuracy: 0.3750 - val_loss: 1.5144
# Epoch 85/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8999 - loss: 0.4708 - val_accuracy: 0.3750 - val_loss: 1.5439
# Epoch 86/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8341 - loss: 0.4477 - val_accuracy: 0.3750 - val_loss: 1.5814
# Epoch 87/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7961 - loss: 0.5190 - val_accuracy: 0.3750 - val_loss: 1.6072
# Epoch 88/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7457 - loss: 0.6078 - val_accuracy: 0.3750 - val_loss: 1.6224
# Epoch 89/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8926 - loss: 0.3357 - val_accuracy: 0.3750 - val_loss: 1.6208
# Epoch 90/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8324 - loss: 0.4417 - val_accuracy: 0.3750 - val_loss: 1.6105
# Epoch 91/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8593 - loss: 0.4216 - val_accuracy: 0.3750 - val_loss: 1.6017
# Epoch 92/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8380 - loss: 0.3604 - val_accuracy: 0.3750 - val_loss: 1.6102
# Epoch 93/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9431 - loss: 0.2746 - val_accuracy: 0.3750 - val_loss: 1.6166
# Epoch 94/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8883 - loss: 0.3824 - val_accuracy: 0.3750 - val_loss: 1.6283
# Epoch 95/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8426 - loss: 0.4317 - val_accuracy: 0.3750 - val_loss: 1.6345
# Epoch 96/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8770 - loss: 0.3883 - val_accuracy: 0.3750 - val_loss: 1.6298
# Epoch 97/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8464 - loss: 0.4051 - val_accuracy: 0.3750 - val_loss: 1.6151
# Epoch 98/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9099 - loss: 0.3805 - val_accuracy: 0.3750 - val_loss: 1.5958
# Epoch 99/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8187 - loss: 0.6640 - val_accuracy: 0.3750 - val_loss: 1.5754
# Epoch 100/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8883 - loss: 0.2861 - val_accuracy: 0.3750 - val_loss: 1.5711
# Epoch 101/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8949 - loss: 0.3995 - val_accuracy: 0.3750 - val_loss: 1.5789
# Epoch 102/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9076 - loss: 0.3254 - val_accuracy: 0.3750 - val_loss: 1.5922
# Epoch 103/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8132 - loss: 0.4509 - val_accuracy: 0.3750 - val_loss: 1.6192
# Epoch 104/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8906 - loss: 0.3154 - val_accuracy: 0.3333 - val_loss: 1.6472
# Epoch 105/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8853 - loss: 0.3504 - val_accuracy: 0.3750 - val_loss: 1.6608
# Epoch 106/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8949 - loss: 0.2947 - val_accuracy: 0.3750 - val_loss: 1.6645
# Epoch 107/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8597 - loss: 0.3709 - val_accuracy: 0.3750 - val_loss: 1.6569
# Epoch 108/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8847 - loss: 0.3156 - val_accuracy: 0.4167 - val_loss: 1.6477
# Epoch 109/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8856 - loss: 0.3438 - val_accuracy: 0.4167 - val_loss: 1.6395
# Epoch 110/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8447 - loss: 0.5052 - val_accuracy: 0.4167 - val_loss: 1.6499
# Epoch 111/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8883 - loss: 0.3594 - val_accuracy: 0.4167 - val_loss: 1.6560
# Epoch 112/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8553 - loss: 0.3366 - val_accuracy: 0.3750 - val_loss: 1.6828
# Epoch 113/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9418 - loss: 0.2932 - val_accuracy: 0.3750 - val_loss: 1.7241
# Epoch 114/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9356 - loss: 0.2341 - val_accuracy: 0.3333 - val_loss: 1.7627
# Epoch 115/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8766 - loss: 0.3362 - val_accuracy: 0.3333 - val_loss: 1.7953
# Epoch 116/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8999 - loss: 0.2941 - val_accuracy: 0.3333 - val_loss: 1.8171
# Epoch 117/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9089 - loss: 0.2927 - val_accuracy: 0.3750 - val_loss: 1.8131
# Epoch 118/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9241 - loss: 0.2491 - val_accuracy: 0.3750 - val_loss: 1.8140
# Epoch 119/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8816 - loss: 0.2830 - val_accuracy: 0.3333 - val_loss: 1.8158
# Epoch 120/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9066 - loss: 0.3414 - val_accuracy: 0.3750 - val_loss: 1.8251
# Epoch 121/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9256 - loss: 0.3173 - val_accuracy: 0.3750 - val_loss: 1.8328
# Epoch 122/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9189 - loss: 0.2603 - val_accuracy: 0.3750 - val_loss: 1.8424
# Epoch 123/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9085 - loss: 0.2998 - val_accuracy: 0.4167 - val_loss: 1.8529
# Epoch 124/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8597 - loss: 0.3110 - val_accuracy: 0.4167 - val_loss: 1.8603
# Epoch 125/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8257 - loss: 0.4745 - val_accuracy: 0.4167 - val_loss: 1.8597
# Epoch 126/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9162 - loss: 0.3250 - val_accuracy: 0.4167 - val_loss: 1.8733
# Epoch 127/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9252 - loss: 0.2674 - val_accuracy: 0.4167 - val_loss: 1.8829
# Epoch 128/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9714 - loss: 0.2624 - val_accuracy: 0.4167 - val_loss: 1.8902
# Epoch 129/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 0.1145 - val_accuracy: 0.3750 - val_loss: 1.9032
# Epoch 130/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9322 - loss: 0.2238 - val_accuracy: 0.3750 - val_loss: 1.9196
# Epoch 131/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8749 - loss: 0.3118 - val_accuracy: 0.3750 - val_loss: 1.9467
# Epoch 132/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9189 - loss: 0.2542 - val_accuracy: 0.3750 - val_loss: 1.9634
# Epoch 133/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9525 - loss: 0.2251 - val_accuracy: 0.3750 - val_loss: 1.9857
# Epoch 134/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9066 - loss: 0.2612 - val_accuracy: 0.3750 - val_loss: 2.0103
# Epoch 135/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9385 - loss: 0.2223 - val_accuracy: 0.3333 - val_loss: 2.0406
# Epoch 136/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9708 - loss: 0.1899 - val_accuracy: 0.3333 - val_loss: 2.0645
# Epoch 137/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9295 - loss: 0.2434 - val_accuracy: 0.3333 - val_loss: 2.0763
# Epoch 138/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9402 - loss: 0.2027 - val_accuracy: 0.2917 - val_loss: 2.0708
# Epoch 139/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9425 - loss: 0.2497 - val_accuracy: 0.2917 - val_loss: 2.0690
# Epoch 140/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9022 - loss: 0.3537 - val_accuracy: 0.2917 - val_loss: 2.0451
# Epoch 141/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9608 - loss: 0.2043 - val_accuracy: 0.3333 - val_loss: 2.0298
# Epoch 142/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8897 - loss: 0.2941 - val_accuracy: 0.3333 - val_loss: 2.0297
# Epoch 143/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9675 - loss: 0.1524 - val_accuracy: 0.3333 - val_loss: 2.0202
# Epoch 144/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9156 - loss: 0.2219 - val_accuracy: 0.3333 - val_loss: 2.0116
# Epoch 145/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9212 - loss: 0.2939 - val_accuracy: 0.3333 - val_loss: 2.0151
# Epoch 146/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9491 - loss: 0.1609 - val_accuracy: 0.3333 - val_loss: 2.0384
# Epoch 147/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9256 - loss: 0.2438 - val_accuracy: 0.3333 - val_loss: 2.0573
# Epoch 148/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8995 - loss: 0.2118 - val_accuracy: 0.3750 - val_loss: 2.0682
# Epoch 149/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8493 - loss: 0.4868 - val_accuracy: 0.3750 - val_loss: 2.0733
# Epoch 150/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9475 - loss: 0.2427 - val_accuracy: 0.3333 - val_loss: 2.0684
# Epoch 151/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9475 - loss: 0.2289 - val_accuracy: 0.3333 - val_loss: 2.0454
# Epoch 152/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9854 - loss: 0.1134 - val_accuracy: 0.3333 - val_loss: 2.0286
# Epoch 153/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8806 - loss: 0.3343 - val_accuracy: 0.3333 - val_loss: 2.0013
# Epoch 154/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9241 - loss: 0.2761 - val_accuracy: 0.3333 - val_loss: 1.9740
# Epoch 155/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9658 - loss: 0.1502 - val_accuracy: 0.3750 - val_loss: 1.9533
# Epoch 156/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8324 - loss: 0.3979 - val_accuracy: 0.3750 - val_loss: 1.9314
# Epoch 157/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8906 - loss: 0.2849 - val_accuracy: 0.3750 - val_loss: 1.9155
# Epoch 158/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9508 - loss: 0.1659 - val_accuracy: 0.4167 - val_loss: 1.9325
# Epoch 159/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9614 - loss: 0.2196 - val_accuracy: 0.4583 - val_loss: 1.9665
# Epoch 160/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9095 - loss: 0.3155 - val_accuracy: 0.4167 - val_loss: 1.9839
# Epoch 161/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9329 - loss: 0.1995 - val_accuracy: 0.4167 - val_loss: 1.9906
# Epoch 162/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.8860 - loss: 0.2922 - val_accuracy: 0.3750 - val_loss: 1.9952
# Epoch 163/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9435 - loss: 0.1651 - val_accuracy: 0.3750 - val_loss: 2.0063
# Epoch 164/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9475 - loss: 0.1483 - val_accuracy: 0.3750 - val_loss: 2.0114
# Epoch 165/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8916 - loss: 0.3586 - val_accuracy: 0.3750 - val_loss: 2.0326
# Epoch 166/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9944 - loss: 0.1132 - val_accuracy: 0.3750 - val_loss: 2.0112
# Epoch 167/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8547 - loss: 0.3534 - val_accuracy: 0.4167 - val_loss: 2.0037
# Epoch 168/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9318 - loss: 0.1693 - val_accuracy: 0.4167 - val_loss: 1.9875
# Epoch 169/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9575 - loss: 0.1590 - val_accuracy: 0.4583 - val_loss: 1.9790
# Epoch 170/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9518 - loss: 0.1525 - val_accuracy: 0.4583 - val_loss: 1.9536
# Epoch 171/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9033 - loss: 0.2962 - val_accuracy: 0.4583 - val_loss: 1.9336
# Epoch 172/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9625 - loss: 0.1710 - val_accuracy: 0.4167 - val_loss: 1.8986
# Epoch 173/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8816 - loss: 0.2715 - val_accuracy: 0.4167 - val_loss: 1.8916
# Epoch 174/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9329 - loss: 0.2267 - val_accuracy: 0.4167 - val_loss: 1.8969
# Epoch 175/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9485 - loss: 0.1723 - val_accuracy: 0.4167 - val_loss: 1.9135
# Epoch 176/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9222 - loss: 0.2121 - val_accuracy: 0.4167 - val_loss: 1.9411
# Epoch 177/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8364 - loss: 0.3122 - val_accuracy: 0.4167 - val_loss: 1.9621
# Epoch 178/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8933 - loss: 0.2532 - val_accuracy: 0.4167 - val_loss: 2.0060
# Epoch 179/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9335 - loss: 0.2604 - val_accuracy: 0.4167 - val_loss: 2.0533
# Epoch 180/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9714 - loss: 0.1994 - val_accuracy: 0.4167 - val_loss: 2.0942
# Epoch 181/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9804 - loss: 0.0987 - val_accuracy: 0.4167 - val_loss: 2.1318
# Epoch 182/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8866 - loss: 0.1762 - val_accuracy: 0.4167 - val_loss: 2.1853
# Epoch 183/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9525 - loss: 0.2161 - val_accuracy: 0.4583 - val_loss: 2.2493
# Epoch 184/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9266 - loss: 0.2145 - val_accuracy: 0.4583 - val_loss: 2.2821
# Epoch 185/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8616 - loss: 0.3466 - val_accuracy: 0.4167 - val_loss: 2.2705
# Epoch 186/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9664 - loss: 0.2107 - val_accuracy: 0.3750 - val_loss: 2.2429
# Epoch 187/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9385 - loss: 0.1459 - val_accuracy: 0.4167 - val_loss: 2.2140
# Epoch 188/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9764 - loss: 0.1073 - val_accuracy: 0.4167 - val_loss: 2.1940
# Epoch 189/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9475 - loss: 0.2060 - val_accuracy: 0.4583 - val_loss: 2.2008
# Epoch 190/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9760 - loss: 0.1001 - val_accuracy: 0.4167 - val_loss: 2.2120
# Epoch 191/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8876 - loss: 0.2187 - val_accuracy: 0.4167 - val_loss: 2.2412
# Epoch 192/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9039 - loss: 0.2215 - val_accuracy: 0.4167 - val_loss: 2.2696
# Epoch 193/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9658 - loss: 0.1425 - val_accuracy: 0.4167 - val_loss: 2.2914
# Epoch 194/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9760 - loss: 0.0864 - val_accuracy: 0.4167 - val_loss: 2.2928
# Epoch 195/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9854 - loss: 0.1320 - val_accuracy: 0.4167 - val_loss: 2.3041
# Epoch 196/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9279 - loss: 0.1610 - val_accuracy: 0.4167 - val_loss: 2.2988
# Epoch 197/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9085 - loss: 0.1948 - val_accuracy: 0.4167 - val_loss: 2.2858
# Epoch 198/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9581 - loss: 0.1480 - val_accuracy: 0.4167 - val_loss: 2.2656
# Epoch 199/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9518 - loss: 0.1565 - val_accuracy: 0.4167 - val_loss: 2.2688
# Epoch 200/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9564 - loss: 0.1572 - val_accuracy: 0.4583 - val_loss: 2.2869
# Epoch 201/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9714 - loss: 0.1143 - val_accuracy: 0.4583 - val_loss: 2.3092
# Epoch 202/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9771 - loss: 0.1219 - val_accuracy: 0.4583 - val_loss: 2.3367
# Epoch 203/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8995 - loss: 0.2243 - val_accuracy: 0.4583 - val_loss: 2.3751
# Epoch 204/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9195 - loss: 0.2626 - val_accuracy: 0.4583 - val_loss: 2.3994
# Epoch 205/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9441 - loss: 0.1514 - val_accuracy: 0.4583 - val_loss: 2.4151
# Epoch 206/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9252 - loss: 0.1800 - val_accuracy: 0.4167 - val_loss: 2.4204
# Epoch 207/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9281 - loss: 0.2712 - val_accuracy: 0.4167 - val_loss: 2.4112
# Epoch 208/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9771 - loss: 0.1065 - val_accuracy: 0.4583 - val_loss: 2.4093
# Epoch 209/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.7991 - loss: 0.6065 - val_accuracy: 0.4583 - val_loss: 2.3800
# Epoch 210/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9352 - loss: 0.2378 - val_accuracy: 0.4583 - val_loss: 2.3572
# Epoch 211/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9804 - loss: 0.1065 - val_accuracy: 0.4583 - val_loss: 2.3573
# Epoch 212/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9185 - loss: 0.2093 - val_accuracy: 0.4583 - val_loss: 2.3795
# Epoch 213/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9431 - loss: 0.1884 - val_accuracy: 0.4583 - val_loss: 2.4045
# Epoch 214/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9435 - loss: 0.1562 - val_accuracy: 0.4167 - val_loss: 2.4212
# Epoch 215/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9425 - loss: 0.1906 - val_accuracy: 0.4583 - val_loss: 2.4434
# Epoch 216/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9764 - loss: 0.1165 - val_accuracy: 0.4583 - val_loss: 2.4835
# Epoch 217/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9095 - loss: 0.1966 - val_accuracy: 0.4583 - val_loss: 2.5008
# Epoch 218/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9704 - loss: 0.0887 - val_accuracy: 0.4583 - val_loss: 2.5018
# Epoch 219/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9764 - loss: 0.1166 - val_accuracy: 0.4583 - val_loss: 2.4966
# Epoch 220/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9368 - loss: 0.1546 - val_accuracy: 0.4583 - val_loss: 2.4882
# Epoch 221/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9302 - loss: 0.2317 - val_accuracy: 0.4167 - val_loss: 2.4707
# Epoch 222/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9268 - loss: 0.1961 - val_accuracy: 0.4583 - val_loss: 2.4807
# Epoch 223/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9714 - loss: 0.1237 - val_accuracy: 0.4583 - val_loss: 2.5040
# Epoch 224/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9452 - loss: 0.1587 - val_accuracy: 0.4167 - val_loss: 2.5234
# Epoch 225/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9591 - loss: 0.1381 - val_accuracy: 0.4167 - val_loss: 2.5244
# Epoch 226/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 1.0000 - loss: 0.0877 - val_accuracy: 0.4167 - val_loss: 2.5249
# Epoch 227/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9804 - loss: 0.1043 - val_accuracy: 0.4583 - val_loss: 2.5277
# Epoch 228/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9335 - loss: 0.1748 - val_accuracy: 0.4583 - val_loss: 2.5121
# Epoch 229/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9614 - loss: 0.1245 - val_accuracy: 0.3333 - val_loss: 2.4935
# Epoch 230/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 1.0000 - loss: 0.0884 - val_accuracy: 0.3333 - val_loss: 2.5046
# Epoch 231/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9435 - loss: 0.1987 - val_accuracy: 0.3333 - val_loss: 2.5150
# Epoch 232/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9045 - loss: 0.1832 - val_accuracy: 0.3750 - val_loss: 2.5200
# Epoch 233/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9691 - loss: 0.1085 - val_accuracy: 0.3750 - val_loss: 2.5167
# Epoch 234/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9854 - loss: 0.0955 - val_accuracy: 0.4167 - val_loss: 2.5084
# Epoch 235/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9854 - loss: 0.0946 - val_accuracy: 0.4167 - val_loss: 2.5133
# Epoch 236/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8803 - loss: 0.2782 - val_accuracy: 0.4167 - val_loss: 2.5639
# Epoch 237/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9771 - loss: 0.1125 - val_accuracy: 0.4167 - val_loss: 2.6181
# Epoch 238/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9341 - loss: 0.1216 - val_accuracy: 0.4167 - val_loss: 2.6334
# Epoch 239/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9422 - loss: 0.1652 - val_accuracy: 0.4167 - val_loss: 2.6143
# Epoch 240/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9239 - loss: 0.2097 - val_accuracy: 0.3750 - val_loss: 2.5934
# Epoch 241/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9631 - loss: 0.0883 - val_accuracy: 0.3750 - val_loss: 2.5677
# Epoch 242/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9581 - loss: 0.0951 - val_accuracy: 0.3750 - val_loss: 2.5640
# Epoch 243/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9441 - loss: 0.1261 - val_accuracy: 0.3750 - val_loss: 2.5616
# Epoch 244/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8962 - loss: 0.2812 - val_accuracy: 0.3750 - val_loss: 2.5159
# Epoch 245/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9525 - loss: 0.1625 - val_accuracy: 0.3750 - val_loss: 2.4843
# Epoch 246/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9179 - loss: 0.2117 - val_accuracy: 0.3750 - val_loss: 2.4838
# Epoch 247/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9508 - loss: 0.2172 - val_accuracy: 0.3750 - val_loss: 2.4913
# Epoch 248/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9235 - loss: 0.1493 - val_accuracy: 0.4167 - val_loss: 2.5095
# Epoch 249/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9531 - loss: 0.1308 - val_accuracy: 0.3750 - val_loss: 2.5417
# Epoch 250/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9860 - loss: 0.0673 - val_accuracy: 0.3750 - val_loss: 2.5582
# Epoch 251/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9464 - loss: 0.1842 - val_accuracy: 0.3750 - val_loss: 2.5665
# Epoch 252/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9575 - loss: 0.0940 - val_accuracy: 0.3750 - val_loss: 2.5491
# Epoch 253/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 0.0567 - val_accuracy: 0.3750 - val_loss: 2.5345
# Epoch 254/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9910 - loss: 0.0479 - val_accuracy: 0.3750 - val_loss: 2.5247
# Epoch 255/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9521 - loss: 0.1085 - val_accuracy: 0.3750 - val_loss: 2.5337
# Epoch 256/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9664 - loss: 0.1255 - val_accuracy: 0.3750 - val_loss: 2.5430
# Epoch 257/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9614 - loss: 0.1394 - val_accuracy: 0.3333 - val_loss: 2.5651
# Epoch 258/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9564 - loss: 0.1051 - val_accuracy: 0.3750 - val_loss: 2.5837
# Epoch 259/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9562 - loss: 0.1305 - val_accuracy: 0.3750 - val_loss: 2.5882
# Epoch 260/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9771 - loss: 0.0739 - val_accuracy: 0.3750 - val_loss: 2.5704
# Epoch 261/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9704 - loss: 0.1067 - val_accuracy: 0.3750 - val_loss: 2.5546
# Epoch 262/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9362 - loss: 0.1909 - val_accuracy: 0.3750 - val_loss: 2.5189
# Epoch 263/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.0448 - val_accuracy: 0.3750 - val_loss: 2.4806
# Epoch 264/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9714 - loss: 0.0888 - val_accuracy: 0.3750 - val_loss: 2.4653
# Epoch 265/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9771 - loss: 0.1464 - val_accuracy: 0.3750 - val_loss: 2.4586
# Epoch 266/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9910 - loss: 0.1377 - val_accuracy: 0.3750 - val_loss: 2.4696
# Epoch 267/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9235 - loss: 0.1861 - val_accuracy: 0.4167 - val_loss: 2.4506
# Epoch 268/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9475 - loss: 0.1024 - val_accuracy: 0.3750 - val_loss: 2.4417
# Epoch 269/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9685 - loss: 0.1621 - val_accuracy: 0.3750 - val_loss: 2.4613
# Epoch 270/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9408 - loss: 0.1639 - val_accuracy: 0.3750 - val_loss: 2.5063
# Epoch 271/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9481 - loss: 0.1140 - val_accuracy: 0.3750 - val_loss: 2.5495
# Epoch 272/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9714 - loss: 0.1410 - val_accuracy: 0.3750 - val_loss: 2.5744
# Epoch 273/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9558 - loss: 0.1579 - val_accuracy: 0.3750 - val_loss: 2.5925
# Epoch 274/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9481 - loss: 0.1403 - val_accuracy: 0.3750 - val_loss: 2.5532
# Epoch 275/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9887 - loss: 0.0896 - val_accuracy: 0.3750 - val_loss: 2.5177
# Epoch 276/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9235 - loss: 0.1572 - val_accuracy: 0.4167 - val_loss: 2.5083
# Epoch 277/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9481 - loss: 0.0927 - val_accuracy: 0.4167 - val_loss: 2.5089
# Epoch 278/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9385 - loss: 0.1434 - val_accuracy: 0.4167 - val_loss: 2.5275
# Epoch 279/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9721 - loss: 0.1375 - val_accuracy: 0.4167 - val_loss: 2.5573
# Epoch 280/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9944 - loss: 0.0955 - val_accuracy: 0.4167 - val_loss: 2.5783
# Epoch 281/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9235 - loss: 0.2680 - val_accuracy: 0.4167 - val_loss: 2.5856
# Epoch 282/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9352 - loss: 0.2286 - val_accuracy: 0.4167 - val_loss: 2.6121
# Epoch 283/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9581 - loss: 0.1514 - val_accuracy: 0.4167 - val_loss: 2.6011
# Epoch 284/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9531 - loss: 0.1128 - val_accuracy: 0.4167 - val_loss: 2.5973
# Epoch 285/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9648 - loss: 0.1266 - val_accuracy: 0.4167 - val_loss: 2.5972
# Epoch 286/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9216 - loss: 0.1651 - val_accuracy: 0.4167 - val_loss: 2.6004
# Epoch 287/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9375 - loss: 0.1713 - val_accuracy: 0.3750 - val_loss: 2.5651
# Epoch 288/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9681 - loss: 0.0970 - val_accuracy: 0.3750 - val_loss: 2.5439
# Epoch 289/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9521 - loss: 0.1178 - val_accuracy: 0.3750 - val_loss: 2.5431
# Epoch 290/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9760 - loss: 0.0920 - val_accuracy: 0.3333 - val_loss: 2.5361
# Epoch 291/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9145 - loss: 0.2396 - val_accuracy: 0.3333 - val_loss: 2.5383
# Epoch 292/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 0.0531 - val_accuracy: 0.3333 - val_loss: 2.5369
# Epoch 293/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9625 - loss: 0.1156 - val_accuracy: 0.3750 - val_loss: 2.5579
# Epoch 294/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9721 - loss: 0.0962 - val_accuracy: 0.3750 - val_loss: 2.5734
# Epoch 295/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9631 - loss: 0.1295 - val_accuracy: 0.3750 - val_loss: 2.5773
# Epoch 296/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9664 - loss: 0.1517 - val_accuracy: 0.3750 - val_loss: 2.5965
# Epoch 297/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9475 - loss: 0.1188 - val_accuracy: 0.3750 - val_loss: 2.6411
# Epoch 298/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8616 - loss: 0.2765 - val_accuracy: 0.3333 - val_loss: 2.6714
# Epoch 299/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9481 - loss: 0.1323 - val_accuracy: 0.3750 - val_loss: 2.7014
# Epoch 300/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9854 - loss: 0.0567 - val_accuracy: 0.3750 - val_loss: 2.7066
# Regularized NN Test Accuracy: 0.5

# %% [markdown]
# After adding Dropout and Batch Normalization, validation accuracy became lower and more unstable compared to the unregularized model. The unregularized model reached validation accuracy around 0.45–0.50, while the regularized model remained closer to 0.33–0.42. More importantly, validation loss for the regularized model increases steadily after early epochs and grows much faster than the non-regularized model, indicating poorer convergence. The regularized network appears to underfit rather than improve generalization.
#
# Given the relatively small dataset size, the original model may not have been severely overfitting, and adding strong regularization (Dropout 0.3) likely reduced the model’s ability to learn meaningful structure. In this case, regularization degraded performance rather than improving it. A better approach would be early stopping instead of heavy dropout. This demonstrates that regularization must be applied proportionally to dataset size and model complexity rather than assumed to always improve results.

# %% [markdown]
# ### Activation Function Experimentation
#
# Different activation functions—ReLU, LeakyReLU, Tanh, and Sigmoid—are tested to evaluate how they influence the neural network’s learning behavior and predictive performance. Comparing results across activation functions helps determine which function provides the most stable training and highest model accuracy.

# %%
# Run activation experiments
import keras
from keras.models import Sequential
from keras.layers import Dense, LeakyReLU
from keras.optimizers import SGD
from sklearn.metrics import accuracy_score

def build_model(activation_name, feature_count, num_classes):
    model = Sequential()
    model.add(Dense(128, input_shape=(feature_count,)))

    if activation_name == "leakyrelu":
        model.add(LeakyReLU(alpha=0.01))
    else:
        model.add(keras.layers.Activation(activation_name))

    model.add(Dense(64))
    if activation_name == "leakyrelu":
        model.add(LeakyReLU(alpha=0.01))
    else:
        model.add(keras.layers.Activation(activation_name))

    model.add(Dense(64))
    if activation_name == "leakyrelu":
        model.add(LeakyReLU(alpha=0.01))
    else:
        model.add(keras.layers.Activation(activation_name))

    model.add(Dense(32))
    if activation_name == "leakyrelu":
        model.add(LeakyReLU(alpha=0.01))
    else:
        model.add(keras.layers.Activation(activation_name))

    model.add(Dense(num_classes, activation="softmax"))
    model.compile(loss="categorical_crossentropy", optimizer=SGD(), metrics=["accuracy"])
    return model

activations = ["relu", "leakyrelu", "tanh", "sigmoid"]
results = []

for act in activations:
    keras.utils.set_random_seed(42)  # reproducibility per run

    m = build_model(act, feature_count, num_classes)
    h = m.fit(
        X_train_nn, y_train_onehot,
        epochs=150,
        batch_size=20,
        validation_split=0.25,
        verbose=0
    )

    # Test accuracy (convert probs -> labels)
    pred_idx = np.argmax(m.predict(X_test_nn, verbose=0), axis=1)
    label_names = y_train.astype("category").cat.categories
    pred_labels = label_names[pred_idx]

    test_acc = accuracy_score(y_test, pred_labels)

    results.append({
        "activation": act,
        "best_val_accuracy": max(h.history["val_accuracy"]),
        "final_val_accuracy": h.history["val_accuracy"][-1],
        "test_accuracy": test_acc
    })

results_df = pd.DataFrame(results).sort_values("test_accuracy", ascending=False)
results_df
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7be791650720> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7be791650720> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
#   activation  best_val_accuracy  final_val_accuracy  test_accuracy
# 2       tanh           0.416667            0.416667       0.547619
# 0       relu           0.500000            0.500000       0.523810
# 1  leakyrelu           0.500000            0.500000       0.523810
# 3    sigmoid           0.166667            0.125000       0.214286

# %% [markdown]
# Activation functions were compared using the same network architecture while only changing the hidden-layer nonlinearity. Tanh performed best, achieving the highest test accuracy (0.548) compared with ReLU (0.524) and LeakyReLU (0.524), while also reaching a stable validation accuracy of 0.417. Sigmoid performed worst with test accuracy 0.214 and very low validation accuracy (0.167 → 0.125), consistent with vanishing-gradient behavior that slows or stalls learning in deeper networks. Overall, the results suggest that tanh provided a better inductive bias for this small, standardized tabular dataset, whereas sigmoid saturated too easily and failed to learn meaningful decision boundaries. ReLU and LeakyReLU remained competitive but slightly underperformed tanh in out-of-sample accuracy.

# %% [markdown]
# ---
#
# ## 8. Explainability – SHAP Feature Importance
#
# In this section, SHAP (SHapley Additive exPlanations) is used to interpret the model’s predictions and analyze feature importance. SHAP assigns each feature a contribution value that represents how much it influences a particular prediction. These values are based on Shapley values from cooperative game theory, which distribute the model’s prediction fairly across all contributing features.

# %%
# Import necessary libraries
import shap
import matplotlib.pyplot as plt

# Transform test data using the fitted preprocessor
X_test_processed = preprocess.transform(X_test)

# Convert sparse matrix to dense if needed (required for SHAP)
if hasattr(X_test_processed, "toarray"):
    X_test_processed = X_test_processed.toarray()

# Extract feature names after preprocessing
# If unavailable, create generic feature names
try:
    feature_names = preprocess.get_feature_names_out()
except:
    feature_names = [f"feature_{i}" for i in range(X_test_processed.shape[1])]

# Initialize SHAP explainer using the trained model
explainer = shap.Explainer(best_model, X_test_processed, feature_names=feature_names)

# Compute SHAP values for the test set
shap_values = explainer(X_test_processed)

# Generate SHAP summary plot to visualize global feature importance
shap.summary_plot(shap_values, X_test_processed, feature_names=feature_names)
# Out:
# /tmp/ipykernel_303/1936293753.py:26: FutureWarning: The NumPy global RNG was seeded by calling `np.random.seed`. In a future version this function will no longer use the global RNG. Pass `rng` explicitly to opt-in to the new behaviour and silence this warning.
#   shap.summary_plot(shap_values, X_test_processed, feature_names=feature_names)

# %% [markdown]
# ### Experimentation

# %%
# PCA + Logistic Regression
from sklearn.decomposition import PCA
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

X_train_p = preprocess.transform(X_train)
X_test_p  = preprocess.transform(X_test)
X_train_p = X_train_p.toarray() if hasattr(X_train_p, "toarray") else X_train_p
X_test_p  = X_test_p.toarray() if hasattr(X_test_p, "toarray") else X_test_p

pca = PCA(n_components=0.95, random_state=42)
X_train_pca = pca.fit_transform(X_train_p)
X_test_pca  = pca.transform(X_test_p)

lr = LogisticRegression(max_iter=5000)
lr.fit(X_train_pca, y_train)
pred_pca = lr.predict(X_test_pca)

print("PCA + LogReg Test Accuracy:", accuracy_score(y_test, pred_pca))
print(classification_report(y_test, pred_pca))
# Out:
# PCA + LogReg Test Accuracy: 0.5
#               precision    recall  f1-score   support
#
#      Average       0.50      0.62      0.56         8
#         High       0.50      0.38      0.43         8
#          Low       0.31      0.50      0.38         8
#    Very High       0.88      0.78      0.82         9
#     Very Low       0.40      0.22      0.29         9
#
#     accuracy                           0.50        42
#    macro avg       0.52      0.50      0.49        42
# weighted avg       0.52      0.50      0.50        42

# %% [markdown]
# The PCA + Logistic Regression model achieved a test accuracy of 0.50, which is lower than the neural network model (0.62) and slightly below the regularized Random Forest (0.52). While PCA successfully reduced dimensionality and addressed multicollinearity among highly correlated development indicators, the linear decision boundaries of Logistic Regression appear insufficient to fully capture the structure of the dataset. Although the model performs well in the “Very High” category (F1 = 0.82), performance is weaker in “Very Low” (F1 = 0.29) and moderate across middle categories. This suggests that happiness classification depends on nonlinear interactions between socioeconomic variables rather than purely linear combinations of principal components. Overall, the results indicate that dimensionality reduction alone does not compensate for the need for nonlinear modeling capacity in this problem.

# %% [markdown]
# Deep learning models are often considered "black boxes" due to their complexity. Use SHAP to explain your model's predictions.
#
# After applying SHAP, discuss:
#
# - Does it provide a clear and sufficient explanation of how the model makes decisions?
# - How easy or difficult is it to justify your model's predictions using this technique?

# %%
import shap

# Select background (runtime control)

np.random.seed(42)

bg_idx = np.random.choice(X_train_nn.shape[0], size=min(30, X_train_nn.shape[0]), replace=False)
background = X_train_nn[bg_idx]

explain_idx = np.random.choice(X_test_nn.shape[0], size=min(20, X_test_nn.shape[0]), replace=False)
X_explain = X_test_nn[explain_idx]

# SHAP needs a predict_proba-style function for multiclass

def predict_proba(x):
    return keras_model.predict(x, verbose=0)

# Build explainer + compute SHAP values

explainer_nn = shap.KernelExplainer(predict_proba, background)
shap_values_nn = explainer_nn.shap_values(X_explain, nsamples=200)

# Feature names must match preprocessed feature count

try:
    feature_names = list(preprocess.get_feature_names_out())
except:
    feature_names = [f"feature_{i}" for i in range(X_explain.shape[1])]

# Normalize SHAP output shape to (n_samples, n_features) for one class

if isinstance(shap_values_nn, list):
    # One array per class: choose a class to visualize (e.g., last class)
    class_index = len(shap_values_nn) - 1
    sv = shap_values_nn[class_index]
else:
    sv = np.array(shap_values_nn)
    if sv.ndim == 3:
        # Handle both possible layouts
        if sv.shape[0] == X_explain.shape[0] and sv.shape[1] == X_explain.shape[1]:
            class_index = sv.shape[2] - 1
            sv = sv[:, :, class_index]
        else:
            class_index = sv.shape[0] - 1
            sv = sv[class_index, :, :]
    elif sv.ndim == 2:
        pass

# Safety check to prevent shape mismatch error
assert sv.shape == X_explain.shape, f"Mismatch: SHAP {sv.shape} vs X {X_explain.shape}"


# Global explanation plot

shap.summary_plot(sv, X_explain, feature_names=feature_names)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# /tmp/ipykernel_303/3512805709.py:55: FutureWarning: The NumPy global RNG was seeded by calling `np.random.seed`. In a future version this function will no longer use the global RNG. Pass `rng` explicitly to opt-in to the new behaviour and silence this warning.
#   shap.summary_plot(sv, X_explain, feature_names=feature_names)

# %% [markdown]
# After applying SHAP to the neural network, the summary plot shows that the model’s predictions are primarily driven by economic and development-related variables, particularly GDP-related measures, interaction terms, freedom to make life choices, and perceptions of corruption. Higher values of these features generally push predictions toward higher happiness categories, while lower values shift predictions downward. This confirms that the neural network is relying on economically meaningful signals rather than arbitrary noise.
#
# SHAP provides a reasonably clear global explanation of feature importance and directional impact. It is effective for verifying whether the model is using sensible variables and for identifying which features contribute most to predictions. However, explaining individual predictions remains moderately complex. Because the neural network operates on scaled and encoded features and captures nonlinear interactions, translating SHAP values into a simple, intuitive narrative requires careful interpretation. Therefore, SHAP improves transparency, but deep learning models remain more difficult to justify at a case-specific level compared to simpler or tree-based models.

# %%
import nbformat

nb = nbformat.read("/content/drive/MyDrive/Projects in ML/QMSSGR5074_Project_1_Group6.ipynb", as_version=4)

if "widgets" in nb.metadata:
    del nb.metadata["widgets"]

nbformat.write(nb, "QMSSGR5074_Project_1_Group6_clean.ipynb")
